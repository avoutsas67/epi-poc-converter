# %%
import sys, os
module_path = os.path.abspath(os.path.join('..'))
module_path = os.path.join(module_path, 'scripts')
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pprint
import pandas as pd
import uuid
import json
import os
import glob
import re
import sys
from bs4 import NavigableString, BeautifulSoup
from collections import defaultdict
import random
import string

from utils.config import config
from utils.logger.logger import loggerCreator
from requests.exceptions import HTTPError

## ePI Modules
from parse.rulebook.rulebook import StyleRulesDictionary

from parse.extractor.parser import parserExtractor
from match.matchDocument.matchDocument import MatchDocument
from documentAnnotation.documentAnnotation import DocumentAnnotation
from htmlDocTypePartitioner.partition import DocTypePartitioner
from extractContentBetweenHeadings.dataBetweenHeadingsExtractor import DataBetweenHeadingsExtractor
from fhirXmlGenerator.fhirXmlGenerator import FhirXmlGenerator
from fhirService.fhirService import FhirService

# %load_ext autoreload

# %autoreload 2

# %%
def getRandomString(N):
    str_ = ''.join(random.choice(string.ascii_uppercase + string.digits \
            + string.ascii_lowercase) for _ in range(N))
    return str_

# %% [markdown]
# # Set Required Field for Parsing and Partition Modules

# %% [markdown]
# ### Please ensure that your converted_html folder has html files in their specific language folders
#
# Example: If your language code is en, please ensure that all html files reside in the converted_html/en folder. If folder is not present, a folder not found exception will be thrown

# %% [markdown]
# ### English

# %%
ePILanguage = 'en'
fileNameQrd = 'qrd_canonical_mode_CAP_NAP.csv'
procedureType = 'CAP'

# %% [markdown]
# ### German

# %%
ePILanguage = 'de'
fileNameQrd = 'qrd_canonical_mode_CAP_NAP.csv'
procedureType = 'CAP'

# %% [markdown]
# ### Spanish

# %%
ePILanguage = 'es'
fileNameQrd = 'qrd_canonical_mode_CAP_NAP.csv'
procedureType = 'CAP'

# %% [markdown]
# # Html Parsing Stage

# %%
class FolderNotFoundError(Exception):
    pass

## Generate input folder path
module_path = os.path.abspath(os.path.join('..'))
module_path = os.path.join(module_path, 'data')
module_path = os.path.join(module_path, 'converted_to_html')
module_path = os.path.join(module_path, ePILanguage)

## Generate output folder path
output_json_path = module_path.replace('converted_to_html','outputJSON')

"""
    Check if input folder exists, else throw exception
"""
if(os.path.exists(module_path)):
    filenames = glob.glob(os.path.join(module_path, '*.html'))
    filenames.extend(glob.glob(os.path.join(module_path, '*.htm')))
    
    ## Create language specific folder in outputJSON folder if it doesn't exist
    if(not os.path.exists(output_json_path)):
        os.mkdir(output_json_path)
    logger = loggerCreator('Parser_'+ getRandomString(1))
    
    styleRulesObj = StyleRulesDictionary(loggerCreator('Style Dictionary_'+ getRandomString(1)),
                                     language = ePILanguage,
                                     fileName = fileNameQrd,
                                     procedureType = procedureType)

    parserObj = parserExtractor(config, logger, styleRulesObj.styleRuleDict, 
                            styleRulesObj.styleFeatureKeyList, 
                            styleRulesObj.qrd_section_headings)

    for input_filename in filenames:
#     if(input_filename.find('emea-combined-h-2494-es')!=-1):
        output_filename = input_filename.replace('converted_to_html','outputJSON')
        output_filename = output_filename.replace('.html','.json')
        output_filename = output_filename.replace('.htm','.json')
        print(input_filename, output_filename)
        parserObj.createPIJsonFromHTML(input_filepath = input_filename,
                                       output_filepath = output_filename,
                                       img_base64_dict= parserObj.convertImgToBase64(input_filename),
                                      )
else:
    raise FolderNotFoundError(module_path + " not found")
# Out:
# 2021-04-28 14:05:39,012 : Style Dictionary_l : Creating default style dictionary in file: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\styleRules\rule_dictionary_es.json
# 2021-04-28 14:05:39,049 : Style Dictionary_l : Qrd Section Keys Generated: ANEXO I, ANEXO II, ANEXO III, B. PROSPECTO
# C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\converted_to_html\es\emea-combined-h-2494-es.htm C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\outputJSON\es\emea-combined-h-2494-es.json
# 2021-04-28 14:05:44,023 : Parser_T : Writing to file: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\outputJSON\es\emea-combined-h-2494-es.json

# %% [markdown]
# # Partition Stage

# %%
styleRulesObj = StyleRulesDictionary(loggerCreator('Style Dictionary_'+ getRandomString(1)), 
                                     language = ePILanguage,
                                     fileName = fileNameQrd,
                                     procedureType = procedureType)

path_json = os.path.join(os.path.abspath(os.path.join('..')), 'data', 'outputJSON', ePILanguage)

partitionlogger = loggerCreator('Partition_'+ getRandomString(1))
partitioner = DocTypePartitioner(partitionlogger)
partitioner.partitionHtmls(styleRulesObj.qrd_section_headings, path_json)
# Out:
# 2021-04-26 14:47:47,706 : Style Dictionary_K : Reading style dictionary in file: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\styleRules\rule_dictionary_de.json
# 2021-04-26 14:47:47,742 : Style Dictionary_K : Qrd Section Keys Generated: ANHANG I, ANHANG II, ANHANG III, B. PACKUNGSBEILAGE
# 2021-04-26 14:47:47,744 : Partition_g : Partitioning Json: emea-combined-h-2494-de.json
# *************************** Texts with more than 2 characters**************************************
#                                                                                                                                                                                                     Element  \
# 0   <div class="WordSection1"> <p align="center" class="MsoNormal" style="text-align:center"><b><span lang="DE"> </span></b></p> <p align="center" class="MsoNormal" style="text-align:center"><b><span ...
# 24                                                                              <p align="center" class="MsoNormal" style="text-align:center;line-height:13.0pt"><b><span lang="DE">ANHANG I</span></b></p>
# 26                                                                                                              <p class="TitleA"><span lang="DE">ZUSAMMENFASSUNG DER MERKMALE DES ARZNEIMITTELS</span></p>
# 33                                   <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;page-break-after: avoid"><b><span lang="DE">1.       BEZEICHNUNG DES ARZNEIMITTELS</span></b></p>
# 35                                                                                                                             <p class="MsoNormal"><span lang="DE">Kalydeco 75 mg Filmtabletten</span></p>
#
#                                       ID  \
# 0   c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 24  b08f51ee-2061-4632-b2b8-90cbc4d6ad39
# 26  02271640-d5b1-47a5-99b5-22a5f3f876ea
# 33  973c38f0-80b6-4d2c-94dd-d904a8941a74
# 35  c6d7d7ff-c831-4eaf-83df-0b6617b839d8
#
#                                                                Styles  \
# 0                                                                None
# 24                               text-align:center;line-height:13.0pt
# 26                                                               None
# 33  margin-left:28.35pt;text-indent:-28.35pt;page-break-after:\navoid
# 35                                                               None
#
#              Classes   Bold  Italics  Uppercased  Underlined  Indexed  \
# 0   ['WordSection1']  False    False       False       False    False
# 24     ['MsoNormal']   True    False        True       False    False
# 26        ['TitleA']   True    False        True       False    False
# 33     ['MsoNormal']   True    False        True       False     True
# 35     ['MsoNormal']  False    False       False       False    False
#
#     IsListItem  HasBorder  IsPossibleHeading IsHeadingType  \
# 0        False      False              False          None
# 24       False      False               True          None
# 26       False      False              False          None
# 33       False      False               True            L1
# 35       False      False              False          None
#
#                                                                                                                                                                                                        Text  \
# 0                                                                                                                                                                                                       ...
# 24                                                                                                                                                                                                 ANHANG I
# 26                                                                                                                                                           ZUSAMMENFASSUNG DER MERKMALE DES ARZNEIMITTELS
# 33                                                                                                                                                                   1.       BEZEICHNUNG DES ARZNEIMITTELS
# 35                                                                                                                                                                             Kalydeco 75 mg Filmtabletten
#
#                                 ParentId
# 0   3eb2e153-bc1e-4848-b7db-42b79c750fa7
# 24  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 26  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 33  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 35  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 2021-04-26 14:47:47,929 : Partition_g : Writing partition to file: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\partitionedJSONs\de\emea-combined-h-2494-de_SmPC.json
# *************************** Texts with more than 2 characters**************************************
#                                                                                                                                                                                                       Element  \
# 1246                                                               <p align="center" class="MsoNormal" style="text-align:center"><b><span lang="DE" style="text-transform:uppercase">ANhang II</span></b></p>
# 1248  <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom: 0in;margin-left:85.05pt;margin-bottom:.0001pt;text-indent:-35.4pt;line-height: 13.0pt"><b><span lang="DE">A.        HE...
# 1250  <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom: 0in;margin-left:85.05pt;margin-bottom:.0001pt;text-indent:-35.4pt;line-height: 13.0pt"><b><span lang="DE">B.        BE...
# 1252  <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom: 0in;margin-left:85.05pt;margin-bottom:.0001pt;text-indent:-35.4pt;line-height: 13.0pt"><b><span lang="DE">C.        </...
# 1254  <p class="NormalAgency" style="margin-left:85.05pt;text-indent:-35.4pt"><b><span lang="DE" style='font-size:11.0pt;font-family:"Times New Roman",serif'>D.</span></b><span lang="DE" style='font-siz...
#
#                                         ID  \
# 1246  a368e379-aa0d-40c9-87b9-d28db934159e
# 1248  cab7b27a-7d40-404a-aa64-9af8779b0e62
# 1250  d90aa509-eb21-463c-9b0a-6753dd0a3d80
# 1252  49d0759e-f742-4b48-a165-8aafe5ef8caa
# 1254  cac700fc-c655-4cac-a82b-ecc4334f65f6
#
#                                                                                                                                          Styles  \
# 1246                                                                                                                          text-align:center
# 1248  margin-top:0in;margin-right:70.8pt;margin-bottom:\n0in;margin-left:85.05pt;margin-bottom:.0001pt;text-indent:-35.4pt;line-height:\n13.0pt
# 1250  margin-top:0in;margin-right:70.8pt;margin-bottom:\n0in;margin-left:85.05pt;margin-bottom:.0001pt;text-indent:-35.4pt;line-height:\n13.0pt
# 1252  margin-top:0in;margin-right:70.8pt;margin-bottom:\n0in;margin-left:85.05pt;margin-bottom:.0001pt;text-indent:-35.4pt;line-height:\n13.0pt
# 1254                                                                                                    margin-left:85.05pt;text-indent:-35.4pt
#
#                Classes  Bold  Italics  Uppercased  Underlined  Indexed  \
# 1246     ['MsoNormal']  True    False        True       False    False
# 1248     ['MsoNormal']  True    False        True       False     True
# 1250     ['MsoNormal']  True    False        True       False     True
# 1252     ['MsoNormal']  True    False        True       False     True
# 1254  ['NormalAgency']  True    False        True       False     True
#
#       IsListItem  HasBorder  IsPossibleHeading IsHeadingType  \
# 1246       False      False               True          None
# 1248       False      False               True            L1
# 1250       False      False               True            L1
# 1252       False      False               True            L1
# 1254       False      False               True            L1
#
#                                                                                                      Text  \
# 1246                                                                                            ANhang II
# 1248                               A.        HERSTELLER, DER  FÜR DIE CHARGENFREIGABE VERANTWORTLICH IST
# 1250                           B.        BEDINGUNGEN ODER EINSCHRÄNKUNGEN FÜR DIE ABGABE UND DEN GEBRAUCH
# 1252                 C.        SONSTIGE BEDINGUNGEN UND AUFLAGEN DER GENEHMIGUNG FÜR DAS INVERKEHRBRINGEN
# 1254  D.        BEDINGUNGEN ODER EINSCHRÄNKUNGEN FÜR DIE SICHERE UND WIRKSAME ANWENDUNG DES ARZNEIMITTELS
#
#                                   ParentId
# 1246  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1248  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1250  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1252  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1254  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 2021-04-26 14:47:48,025 : Partition_g : Writing partition to file: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\partitionedJSONs\de\emea-combined-h-2494-de_ANHANG II.json
# *************************** Texts with more than 2 characters**************************************
#                                                                                                                                                                                                       Element  \
# 1331                                                                                               <p align="center" class="MsoNormal" style="text-align:center"><b><span lang="DE">ANHANG III</span></b></p>
# 1333                                                                        <p align="center" class="MsoNormal" style="text-align:center"><b><span lang="DE">ETIKETTIERUNG UND PACKUNGSBEILAGE</span></b></p>
# 1359                                                                                                                                            <p class="TitleA"><span lang="DE">A. ETIKETTIERUNG</span></p>
# 1363  <div style="border:solid windowtext 1.0pt;padding:1.0pt 4.0pt 1.0pt 4.0pt"> <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;border:none; padding:0in"><b><span lang="DE">ANGABE...
# 1364                                      <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;border:none; padding:0in"><b><span lang="DE">ANGABEN AUF DER ÄUSSEREN UMHÜLLUNG</span></b></p>
#
#                                         ID  \
# 1331  e955a9a7-a525-46ea-849a-d4757b825ce9
# 1333  ca906ac9-5429-44ad-851d-fb8fec3165b5
# 1359  d1e1a849-437a-4d31-bc5f-2fd1a26c031c
# 1363  e90f9bbd-c944-40a9-b219-85a19b9c13a6
# 1364  a7e27c18-266b-4ad4-a142-45361d45123d
#
#                                                                   Styles  \
# 1331                                                   text-align:center
# 1333                                                   text-align:center
# 1359                                                                None
# 1363       border:solid windowtext 1.0pt;padding:1.0pt 4.0pt 1.0pt 4.0pt
# 1364  margin-left:28.35pt;text-indent:-28.35pt;border:none;\npadding:0in
#
#             Classes   Bold  Italics  Uppercased  Underlined  Indexed  \
# 1331  ['MsoNormal']   True    False        True       False    False
# 1333  ['MsoNormal']   True    False        True       False    False
# 1359     ['TitleA']   True    False        True       False     True
# 1363           None  False    False       False       False    False
# 1364  ['MsoNormal']   True    False        True       False    False
#
#       IsListItem  HasBorder  IsPossibleHeading IsHeadingType  \
# 1331       False      False               True            L1
# 1333       False      False               True            L1
# 1359       False      False               True            L2
# 1363       False       True              False          None
# 1364       False      False               True            L1
#
#                                     Text                              ParentId
# 1331                          ANHANG III  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1333   ETIKETTIERUNG UND PACKUNGSBEILAGE  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1359                    A. ETIKETTIERUNG  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1363                                      c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 1364  ANGABEN AUF DER ÄUSSEREN UMHÜLLUNG  e90f9bbd-c944-40a9-b219-85a19b9c13a6
# 2021-04-26 14:47:48,104 : Partition_g : Writing partition to file: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\partitionedJSONs\de\emea-combined-h-2494-de_ANHANG III.json
# *************************** Texts with more than 2 characters**************************************
#                                                                                                                                                    Element  \
# 3213                                                                                       <p class="TitleA"><span lang="DE">B. PACKUNGSBEILAGE</span></p>
# 3217       <p align="center" class="MsoNormal" style="text-align:center"><b><span lang="DE">Gebrauchsinformation: Information für Patienten</span></b></p>
# 3219   <p align="center" class="MsoNormal" style="text-align:center;page-break-after:avoid"><b><span lang="DE">Kalydeco 75 mg Filmtabletten</span></b></p>
# 3220  <p align="center" class="MsoNormal" style="text-align:center;page-break-after:avoid"><b><span lang="DE">Kalydeco 150 mg Filmtabletten</span></b></p>
# 3221                             <p align="center" class="MsoNormal" style="text-align:center;page-break-after:avoid"><span lang="DE">Ivacaftor</span></p>
#
#                                         ID  \
# 3213  c3972417-d66d-4cc5-88fa-c647e224fc9e
# 3217  9d399792-f8ff-42f1-889c-ab23e7bfd23d
# 3219  11415641-b57c-46e4-872f-c3ce9a3b2c81
# 3220  e9fd8074-4c9e-4a82-848d-360d49e10c2f
# 3221  67477362-c7bc-4474-88e3-35322973a8ec
#
#                                         Styles        Classes   Bold  Italics  \
# 3213                                      None     ['TitleA']   True    False
# 3217                         text-align:center  ['MsoNormal']   True    False
# 3219  text-align:center;page-break-after:avoid  ['MsoNormal']   True    False
# 3220  text-align:center;page-break-after:avoid  ['MsoNormal']   True    False
# 3221  text-align:center;page-break-after:avoid  ['MsoNormal']  False    False
#
#       Uppercased  Underlined  Indexed  IsListItem  HasBorder  \
# 3213        True       False     True       False      False
# 3217       False       False    False       False      False
# 3219       False       False    False       False      False
# 3220       False       False    False       False      False
# 3221       False       False    False       False      False
#
#       IsPossibleHeading IsHeadingType  \
# 3213               True          None
# 3217               True            L2
# 3219               True            L2
# 3220               True            L2
# 3221              False          None
#
#                                                  Text  \
# 3213                               B. PACKUNGSBEILAGE
# 3217  Gebrauchsinformation: Information für Patienten
# 3219                     Kalydeco 75 mg Filmtabletten
# 3220                    Kalydeco 150 mg Filmtabletten
# 3221                                        Ivacaftor
#
#                                   ParentId
# 3213  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 3217  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 3219  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 3220  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 3221  c2fa6683-2938-4ca2-90fe-b6f8c775a015
# 2021-04-26 14:47:48,143 : Partition_g : Writing partition to file: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\partitionedJSONs\de\emea-combined-h-2494-de_ PACKUNGSBEILAGE.json

# %% [markdown]
# # Matching Stage

# %%
# Set variables for the specific section.

previousHeadingRowFound = None
procedureType = 'CAP'
languageCode = 'en'
documentType = 'SmPC'
stopWordlanguage = 'english'
docFilter = 'SmPC.json'
fileNameDoc = 'Kalydeco II-86-PI-clean_SmPC.json'
fileNameQrd = 'qrd_canonical_mode_CAP_NAP.csv'
fileNameMatchRuleBook = 'ruleDict.json'

stopWordFilterLen = 6 
topHeadingsConsidered = 4
bottomHeadingsConsidered = 6
isPackageLeaflet = False

# %%
previousHeadingRowFound = None
procedureType = 'CAP'
languageCode = 'en'
documentType = 'AnnexII'
stopWordlanguage = 'english'
docFilter = 'ANNEX II.json'
fileNameDoc = 'Abilify-h-471-e_ANNEX II.json'
fileNameQrd = 'qrd_canonical_mode_CAP_NAP.csv'
fileNameMatchRuleBook = 'ruleDict.json'

stopWordFilterLen = 6 
topHeadingsConsidered = 4
bottomHeadingsConsidered = 6
isPackageLeaflet = False

# %%
# Set variables for the specific section.

previousHeadingRowFound = None
procedureType = 'CAP'
languageCode = 'en'
documentType = 'Package leaflet'
stopWordlanguage = 'english'
docFilter = 'LEAFLET.json'
fileNameDoc = 'Abilify-h-471-e_ PACKAGE LEAFLET.json'
fileNameQrd = 'qrd_canonical_mode_CAP_NAP.csv'
fileNameMatchRuleBook = 'ruleDict.json'

stopWordFilterLen = 100
topHeadingsConsidered = 5
bottomHeadingsConsidered = 10
isPackageLeaflet = True

# %%
matchDocObj = MatchDocument(procedureType,
                 languageCode,
                 documentType,
                 fileNameDoc,
                 fileNameQrd,
                 fileNameMatchRuleBook,
                 topHeadingsConsidered,
                 bottomHeadingsConsidered,
                 stopWordFilterLen,
                 stopWordlanguage,
                 isPackageLeaflet)
# Out:
# File being processed: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\partitionedJSONs\en\Kalydeco II-86-PI-clean_SmPC.json
# --------------------------------------------

# %%
    df, coll = matchDocObj.matchHtmlHeaddingsWithQrd()
# Out:
# True  ||  <=7|3.12|(98, 97, 98)|0.99|  ||  1.       NAME OF THE MEDICINAL PRODUCT  ||  1 NAME OF THE MEDICINAL PRODUCT
# True  ||  <=7|2.33|(99, 98, 99)|0.99|  ||  2.       QUALITATIVE AND QUANTITATIVE COMPOSITION  ||  2 QUALITATIVE AND QUANTITATIVE COMPOSITION
# True  ||  <=4|11.11|(95, 89, 95)|0.99|  ||  Excipient with known effect  ||  Excipient(s) with known effect
# True  ||  <=4|4.55|(98, 95, 98)|0.98|  ||  3.       PHARMACEUTICAL FORM  ||  3 PHARMACEUTICAL FORM
# True  ||  <=4|4.35|(98, 95, 98)|0.99|  ||  4.       CLINICAL PARTICULARS  ||  4 CLINICAL PARTICULARS
# True  ||    ||  4.1     Therapeutic indications  ||  4.1 Therapeutic indications
# True  ||    ||  4.2     Posology and method of administration  ||  4.2 Posology and method of administration
# True  ||    ||  Posology  ||  Posology
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  4.3       Contraindications  ||  4.3 Contraindications
# True  ||    ||  4.4       Special warnings and precautions for use  ||  4.4 Special warnings and precautions for use
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  4.5          Interaction with other medicinal products and other forms of interaction  ||  4.5 Interaction with other medicinal products and other forms of interaction
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  4.6    Fertility, pregnancy and lactation  ||  4.6 Fertility, pregnancy and lactation
# True  ||    ||  Pregnancy  ||  Pregnancy
# True  ||  <=1|7.14|(93, 93, 100)|0.98|  ||  Breast‑feeding  ||  Breast-feeding
# True  ||    ||  Fertility  ||  Fertility
# True  ||    ||  4.7     Effects on ability to drive and use machines  ||  4.7 Effects on ability to drive and use machines
# True  ||    ||  4.8     Undesirable effects  ||  4.8 Undesirable effects
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  Reporting of suspected adverse reactions  ||  Reporting of suspected adverse reactions
# True  ||    ||  4.9       Overdose  ||  4.9 Overdose
# True  ||  <=4|3.45|(98, 96, 98)|0.99|  ||  5.       PHARMACOLOGICAL PROPERTIES  ||  5 PHARMACOLOGICAL PROPERTIES
# True  ||    ||  5.1          Pharmacodynamic properties  ||  5.1 Pharmacodynamic properties
# True  ||    ||  Mechanism of action  ||  Mechanism of action
# True  ||    ||  Pharmacodynamic effects  ||  Pharmacodynamic effects
# True  ||    ||  Clinical efficacy and safety  ||  Clinical efficacy and safety
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  5.2     Pharmacokinetic properties  ||  5.2 Pharmacokinetic properties
# True  ||    ||  Absorption  ||  Absorption
# True  ||    ||  Distribution  ||  Distribution
# True  ||    ||  Biotransformation  ||  Biotransformation
# True  ||    ||  Elimination  ||  Elimination
# True  ||  <=1|4.35|(96, 96, 100)|0.99|  ||  Linearity/non‑linearity  ||  Linearity/non-linearity
# True  ||    ||  5.3     Preclinical safety data  ||  5.3 Preclinical safety data
# True  ||  <=4|3.45|(98, 96, 98)|0.99|  ||  6.       PHARMACEUTICAL PARTICULARS  ||  6 PHARMACEUTICAL PARTICULARS
# True  ||    ||  6.1     List of excipients  ||  6.1 List of excipients
# True  ||    ||  6.2     Incompatibilities  ||  6.2 Incompatibilities
# True  ||    ||  6.3     Shelf life  ||  6.3 Shelf life
# True  ||    ||  6.4     Special precautions for storage  ||  6.4 Special precautions for storage
# True  ||  Contains<>|158.33|(48, 81, 86)|0.69|  ||  6.5     Nature and contents of container  ||  6.5 Nature and contents of container <and special equipment for use administration or implantation>
# True  ||  Contains<>|14.63|(93, 90, 95)|0.93|  ||  6.6    Special precautions for disposal and other handling  ||  6.6 Special precautions for disposal <and other handling>
# True  ||  <=4|3.03|(98, 97, 98)|0.99|  ||  7.       MARKETING AUTHORISATION HOLDER  ||  7 MARKETING AUTHORISATION HOLDER
# True  ||  <=4|2.78|(99, 97, 99)|0.99|  ||  8.       MARKETING AUTHORISATION NUMBER(S)  ||  8 MARKETING AUTHORISATION NUMBER(S)
# True  ||  <=7|2.04|(99, 98, 99)|0.99|  ||  9.       DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION  ||  9 DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION
# True  ||  <=4|4.55|(98, 95, 98)|0.98|  ||  10.     DATE OF REVISION OF THE TEXT  ||  10 DATE OF REVISION OF THE TEXT
# oooooooooooooooooooooooooooooooooooooooo END OF Sub Section oooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo
# True  ||  <=7|3.12|(98, 97, 98)|0.99|  ||  1.       NAME OF THE MEDICINAL PRODUCT  ||  1 NAME OF THE MEDICINAL PRODUCT
# True  ||  <=7|2.33|(99, 98, 99)|0.99|  ||  2.       QUALITATIVE AND QUANTITATIVE COMPOSITION  ||  2 QUALITATIVE AND QUANTITATIVE COMPOSITION
# True  ||  <=4|11.11|(95, 89, 95)|0.99|  ||  Excipient with known effect  ||  Excipient(s) with known effect
# True  ||  <=4|11.11|(95, 89, 95)|0.99|  ||  Excipient with known effect  ||  Excipient(s) with known effect
# True  ||  <=4|11.11|(95, 89, 95)|0.99|  ||  Excipient with known effect  ||  Excipient(s) with known effect
# True  ||  <=4|4.55|(98, 95, 98)|0.98|  ||  3.       PHARMACEUTICAL FORM  ||  3 PHARMACEUTICAL FORM
# True  ||  <=4|4.35|(98, 95, 98)|0.99|  ||  4.       CLINICAL PARTICULARS  ||  4 CLINICAL PARTICULARS
# True  ||    ||  4.1     Therapeutic indications  ||  4.1 Therapeutic indications
# True  ||    ||  4.2     Posology and method of administration  ||  4.2 Posology and method of administration
# True  ||    ||  Posology  ||  Posology
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  4.3       Contraindications  ||  4.3 Contraindications
# True  ||    ||  4.4       Special warnings and precautions for use  ||  4.4 Special warnings and precautions for use
# True  ||    ||  Paediatric population   ||  Paediatric population
# True  ||    ||  4.5          Interaction with other medicinal products and other forms of interaction  ||  4.5 Interaction with other medicinal products and other forms of interaction
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  4.6       Fertility, pregnancy and lactation  ||  4.6 Fertility, pregnancy and lactation
# True  ||    ||  Pregnancy  ||  Pregnancy
# True  ||  <=1|7.14|(93, 93, 100)|0.98|  ||  Breast‑feeding  ||  Breast-feeding
# True  ||    ||  Fertility  ||  Fertility
# True  ||    ||  4.7     Effects on ability to drive and use machines  ||  4.7 Effects on ability to drive and use machines
# True  ||    ||  4.8     Undesirable effects  ||  4.8 Undesirable effects
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  Reporting of suspected adverse reactions  ||  Reporting of suspected adverse reactions
# True  ||    ||  4.9       Overdose  ||  4.9 Overdose
# True  ||  <=4|3.45|(98, 96, 98)|0.99|  ||  5.       PHARMACOLOGICAL PROPERTIES  ||  5 PHARMACOLOGICAL PROPERTIES
# True  ||    ||  5.1          Pharmacodynamic properties  ||  5.1 Pharmacodynamic properties
# True  ||    ||  Mechanism of action  ||  Mechanism of action
# True  ||    ||  Pharmacodynamic effects  ||  Pharmacodynamic effects
# True  ||    ||  Clinical efficacy and safety  ||  Clinical efficacy and safety
# True  ||    ||  Paediatric population  ||  Paediatric population
# True  ||    ||  5.2       Pharmacokinetic properties  ||  5.2 Pharmacokinetic properties
# True  ||    ||  Absorption  ||  Absorption
# True  ||    ||  Distribution  ||  Distribution
# True  ||    ||  Biotransformation  ||  Biotransformation
# True  ||    ||  Elimination  ||  Elimination
# True  ||  <=1|4.35|(96, 96, 100)|0.99|  ||  Linearity/non‑linearity  ||  Linearity/non-linearity
# True  ||    ||  5.3     Preclinical safety data  ||  5.3 Preclinical safety data
# True  ||  <=4|3.45|(98, 96, 98)|0.99|  ||  6.       PHARMACEUTICAL PARTICULARS  ||  6 PHARMACEUTICAL PARTICULARS
# True  ||    ||  6.1     List of excipients  ||  6.1 List of excipients
# True  ||    ||  6.2     Incompatibilities  ||  6.2 Incompatibilities
# True  ||    ||  6.3       Shelf life  ||  6.3 Shelf life
# True  ||    ||  6.4     Special precautions for storage  ||  6.4 Special precautions for storage
# True  ||  Contains<>|158.33|(48, 81, 86)|0.69|  ||  6.5     Nature and contents of container  ||  6.5 Nature and contents of container <and special equipment for use administration or implantation>
# True  ||  Contains<>|14.63|(93, 90, 95)|0.93|  ||  6.6     Special precautions for disposal and other handling  ||  6.6 Special precautions for disposal <and other handling>
# True  ||  <=4|3.03|(98, 97, 98)|0.99|  ||  7.       MARKETING AUTHORISATION HOLDER  ||  7 MARKETING AUTHORISATION HOLDER
# True  ||  <=4|2.78|(99, 97, 99)|0.99|  ||  8.       MARKETING AUTHORISATION NUMBER(S)  ||  8 MARKETING AUTHORISATION NUMBER(S)
# True  ||  <=7|2.04|(99, 98, 99)|0.99|  ||  9.       DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION  ||  9 DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION
# True  ||  <=4|4.55|(98, 95, 98)|0.98|  ||  10.     DATE OF REVISION OF THE TEXT  ||  10 DATE OF REVISION OF THE TEXT
#
#
# Heading Not Found
#  ['SUMMARY OF PRODUCT CHARACTERISTICS', 'Method of administration ']

# %% [markdown]
# # Content Extraction Stage

# %%
extractContentlogger = loggerCreator('ExtractContentBetween_'+ getRandomString(1))
extractorObj = DataBetweenHeadingsExtractor(extractContentlogger, coll)
dfExtractedHierRR = extractorObj.extractContentBetweenHeadings(ePILanguage, 'Kalydeco II-86-PI-clean_SmPC.json')
# Out:
# 2021-04-26 20:47:47,647 : ExtractContentBetween_R : Cleaning Match Results
# 2021-04-26 20:47:47,657 : ExtractContentBetween_R : Finished Cleaning Match Results
# 2021-04-26 20:47:47,747 : ExtractContentBetween_R : Extracting Content Between Headings
# 2021-04-26 20:47:47,812 : ExtractContentBetween_R : Finished Extracting Content Between Headings
# File being processed: C:\Users\psaga\source\repos\EMA\EMA%20EPI%20PoC\function_code\data\partitionedJSONs\en\Kalydeco II-86-PI-clean_SmPC.json
# --------------------------------------------
#     index     id Procedure type Display code  \
# 0     682  20003            CAP            1
# 1     683  20004            CAP            2
# 2     686  20007            CAP          NaN
# 3     687  20008            CAP            3
# 4     688  20009            CAP            4
# 5     689  20010            CAP          4.1
# 6     690  20011            CAP          4.2
# 7     691  20012            CAP          NaN
# 8     692  20013            CAP          NaN
# 9     695  20016            CAP          4.3
# 10    696  20017            CAP          4.4
# 11    698  20019            CAP          NaN
# 12    699  20020            CAP          4.5
# 13    700  20021            CAP          NaN
# 14    701  20022            CAP          4.6
# 15    702  20023            CAP          NaN
# 16    703  20024            CAP          NaN
# 17    704  20025            CAP          NaN
# 18    705  20026            CAP          4.7
# 19    706  20027            CAP          4.8
# 20    707  20028            CAP          NaN
# 21    708  20029            CAP          NaN
# 22    709  20030            CAP          4.9
# 23    711  20032            CAP            5
# 24    712  20033            CAP          5.1
# 25    713  20034            CAP          NaN
# 26    714  20035            CAP          NaN
# 27    715  20036            CAP          NaN
# 28    716  20037            CAP          NaN
# 29    717  20038            CAP          5.2
# 30    718  20039            CAP          NaN
# 31    719  20040            CAP          NaN
# 32    720  20041            CAP          NaN
# 33    721  20042            CAP          NaN
# 34    722  20043            CAP          NaN
# 35    724  20045            CAP          5.3
# 36    726  20047            CAP            6
# 37    727  20048            CAP          6.1
# 38    728  20049            CAP          6.2
# 39    729  20050            CAP          6.3
# 40    730  20051            CAP          6.4
# 41    731  20052            CAP          6.5
# 42    732  20053            CAP          6.6
# 43    734  20055            CAP            7
# 44    735  20056            CAP            8
# 45    736  20057            CAP            9
# 46    737  20058            CAP           10
# 47    682  20003            CAP            1
# 48    683  20004            CAP            2
# 49    686  20007            CAP          NaN
# 50    686  20007            CAP          NaN
# 51    686  20007            CAP          NaN
# 52    687  20008            CAP            3
# 53    688  20009            CAP            4
# 54    689  20010            CAP          4.1
# 55    690  20011            CAP          4.2
# 56    691  20012            CAP          NaN
# 57    692  20013            CAP          NaN
# 58    695  20016            CAP          4.3
# 59    696  20017            CAP          4.4
# 60    698  20019            CAP          NaN
# 61    699  20020            CAP          4.5
# 62    700  20021            CAP          NaN
# 63    701  20022            CAP          4.6
# 64    702  20023            CAP          NaN
# 65    703  20024            CAP          NaN
# 66    704  20025            CAP          NaN
# 67    705  20026            CAP          4.7
# 68    706  20027            CAP          4.8
# 69    707  20028            CAP          NaN
# 70    708  20029            CAP          NaN
# 71    709  20030            CAP          4.9
# 72    711  20032            CAP            5
# 73    712  20033            CAP          5.1
# 74    713  20034            CAP          NaN
# 75    714  20035            CAP          NaN
# 76    715  20036            CAP          NaN
# 77    716  20037            CAP          NaN
# 78    717  20038            CAP          5.2
# 79    718  20039            CAP          NaN
# 80    719  20040            CAP          NaN
# 81    720  20041            CAP          NaN
# 82    721  20042            CAP          NaN
# 83    722  20043            CAP          NaN
# 84    724  20045            CAP          5.3
# 85    726  20047            CAP            6
# 86    727  20048            CAP          6.1
# 87    728  20049            CAP          6.2
# 88    729  20050            CAP          6.3
# 89    730  20051            CAP          6.4
# 90    731  20052            CAP          6.5
# 91    732  20053            CAP          6.6
# 92    734  20055            CAP            7
# 93    735  20056            CAP            8
# 94    736  20057            CAP            9
# 95    737  20058            CAP           10
#
#                                                                                                Name  \
# 0                                                                     NAME OF THE MEDICINAL PRODUCT
# 1                                                          QUALITATIVE AND QUANTITATIVE COMPOSITION
# 2                                                                    Excipient(s) with known effect
# 3                                                                               PHARMACEUTICAL FORM
# 4                                                                              CLINICAL PARTICULARS
# 5                                                                           Therapeutic indications
# 6                                                             Posology and method of administration
# 7                                                                                          Posology
# 8                                                                             Paediatric population
# 9                                                                                 Contraindications
# 10                                                         Special warnings and precautions for use
# 11                                                                            Paediatric population
# 12                         Interaction with other medicinal products and other forms of interaction
# 13                                                                            Paediatric population
# 14                                                               Fertility, pregnancy and lactation
# 15                                                                                        Pregnancy
# 16                                                                                   Breast-feeding
# 17                                                                                        Fertility
# 18                                                     Effects on ability to drive and use machines
# 19                                                                              Undesirable effects
# 20                                                                            Paediatric population
# 21                                                         Reporting of suspected adverse reactions
# 22                                                                                         Overdose
# 23                                                                       PHARMACOLOGICAL PROPERTIES
# 24                                                                       Pharmacodynamic properties
# 25                                                                              Mechanism of action
# 26                                                                          Pharmacodynamic effects
# 27                                                                     Clinical efficacy and safety
# 28                                                                            Paediatric population
# 29                                                                       Pharmacokinetic properties
# 30                                                                                       Absorption
# 31                                                                                     Distribution
# 32                                                                                Biotransformation
# 33                                                                                      Elimination
# 34                                                                          Linearity/non-linearity
# 35                                                                          Preclinical safety data
# 36                                                                       PHARMACEUTICAL PARTICULARS
# 37                                                                               List of excipients
# 38                                                                                Incompatibilities
# 39                                                                                       Shelf life
# 40                                                                  Special precautions for storage
# 41  Nature and contents of container <and special equipment for use administration or implantation>
# 42                                            Special precautions for disposal <and other handling>
# 43                                                                   MARKETING AUTHORISATION HOLDER
# 44                                                                MARKETING AUTHORISATION NUMBER(S)
# 45                                         DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION
# 46                                                                     DATE OF REVISION OF THE TEXT
# 47                                                                    NAME OF THE MEDICINAL PRODUCT
# 48                                                         QUALITATIVE AND QUANTITATIVE COMPOSITION
# 49                                                                   Excipient(s) with known effect
# 50                                                                   Excipient(s) with known effect
# 51                                                                   Excipient(s) with known effect
# 52                                                                              PHARMACEUTICAL FORM
# 53                                                                             CLINICAL PARTICULARS
# 54                                                                          Therapeutic indications
# 55                                                            Posology and method of administration
# 56                                                                                         Posology
# 57                                                                            Paediatric population
# 58                                                                                Contraindications
# 59                                                         Special warnings and precautions for use
# 60                                                                            Paediatric population
# 61                         Interaction with other medicinal products and other forms of interaction
# 62                                                                            Paediatric population
# 63                                                               Fertility, pregnancy and lactation
# 64                                                                                        Pregnancy
# 65                                                                                   Breast-feeding
# 66                                                                                        Fertility
# 67                                                     Effects on ability to drive and use machines
# 68                                                                              Undesirable effects
# 69                                                                            Paediatric population
# 70                                                         Reporting of suspected adverse reactions
# 71                                                                                         Overdose
# 72                                                                       PHARMACOLOGICAL PROPERTIES
# 73                                                                       Pharmacodynamic properties
# 74                                                                              Mechanism of action
# 75                                                                          Pharmacodynamic effects
# 76                                                                     Clinical efficacy and safety
# 77                                                                            Paediatric population
# 78                                                                       Pharmacokinetic properties
# 79                                                                                       Absorption
# 80                                                                                     Distribution
# 81                                                                                Biotransformation
# 82                                                                                      Elimination
# 83                                                                          Linearity/non-linearity
# 84                                                                          Preclinical safety data
# 85                                                                       PHARMACEUTICAL PARTICULARS
# 86                                                                               List of excipients
# 87                                                                                Incompatibilities
# 88                                                                                       Shelf life
# 89                                                                  Special precautions for storage
# 90  Nature and contents of container <and special equipment for use administration or implantation>
# 91                                            Special precautions for disposal <and other handling>
# 92                                                                   MARKETING AUTHORISATION HOLDER
# 93                                                                MARKETING AUTHORISATION NUMBER(S)
# 94                                         DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION
# 95                                                                     DATE OF REVISION OF THE TEXT
#
#    parent_id  \
# 0      20001
# 1      20001
# 2      20006
# 3      20001
# 4      20001
# 5      20009
# 6      20009
# 7      20011
# 8      20012
# 9      20009
# 10     20009
# 11     20017
# 12     20009
# 13     20020
# 14     20009
# 15     20022
# 16     20022
# 17     20022
# 18     20009
# 19     20009
# 20     20027
# 21     20027
# 22     20009
# 23     20001
# 24     20032
# 25     20033
# 26     20033
# 27     20033
# 28     20033
# 29     20032
# 30     20038
# 31     20038
# 32     20038
# 33     20038
# 34     20038
# 35     20032
# 36     20001
# 37     20047
# 38     20047
# 39     20047
# 40     20047
# 41     20047
# 42     20047
# 43     20001
# 44     20001
# 45     20001
# 46     20001
# 47     20001
# 48     20001
# 49     20006
# 50     20006
# 51     20006
# 52     20001
# 53     20001
# 54     20009
# 55     20009
# 56     20011
# 57     20012
# 58     20009
# 59     20009
# 60     20017
# 61     20009
# 62     20020
# 63     20009
# 64     20022
# 65     20022
# 66     20022
# 67     20009
# 68     20009
# 69     20027
# 70     20027
# 71     20009
# 72     20001
# 73     20032
# 74     20033
# 75     20033
# 76     20033
# 77     20033
# 78     20032
# 79     20038
# 80     20038
# 81     20038
# 82     20038
# 83     20038
# 84     20032
# 85     20001
# 86     20047
# 87     20047
# 88     20047
# 89     20047
# 90     20047
# 91     20047
# 92     20001
# 93     20001
# 94     20001
# 95     20001
#
#                                                                                  htmlText  \
# 0                                                  1.       NAME OF THE MEDICINAL PRODUCT
# 1                                       2.       QUALITATIVE AND QUANTITATIVE COMPOSITION
# 2                                                             Excipient with known effect
# 3                                                            3.       PHARMACEUTICAL FORM
# 4                                                           4.       CLINICAL PARTICULARS
# 5                                                         4.1     Therapeutic indications
# 6                                           4.2     Posology and method of administration
# 7                                                                                Posology
# 8                                                                   Paediatric population
# 9                                                             4.3       Contraindications
# 10                                     4.4       Special warnings and precautions for use
# 11                                                                  Paediatric population
# 12  4.5          Interaction with other medicinal products and other forms of interaction
# 13                                                                  Paediatric population
# 14                                              4.6    Fertility, pregnancy and lactation
# 15                                                                              Pregnancy
# 16                                                                         Breast‑feeding
# 17                                                                              Fertility
# 18                                   4.7     Effects on ability to drive and use machines
# 19                                                            4.8     Undesirable effects
# 20                                                                  Paediatric population
# 21                                               Reporting of suspected adverse reactions
# 22                                                                     4.9       Overdose
# 23                                                    5.       PHARMACOLOGICAL PROPERTIES
# 24                                                5.1          Pharmacodynamic properties
# 25                                                                    Mechanism of action
# 26                                                                Pharmacodynamic effects
# 27                                                           Clinical efficacy and safety
# 28                                                                  Paediatric population
# 29                                                     5.2     Pharmacokinetic properties
# 30                                                                             Absorption
# 31                                                                           Distribution
# 32                                                                      Biotransformation
# 33                                                                            Elimination
# 34                                                                Linearity/non‑linearity
# 35                                                        5.3     Preclinical safety data
# 36                                                    6.       PHARMACEUTICAL PARTICULARS
# 37                                                             6.1     List of excipients
# 38                                                              6.2     Incompatibilities
# 39                                                                     6.3     Shelf life
# 40                                                6.4     Special precautions for storage
# 41                                               6.5     Nature and contents of container
# 42                             6.6    Special precautions for disposal and other handling
# 43                                                7.       MARKETING AUTHORISATION HOLDER
# 44                                             8.       MARKETING AUTHORISATION NUMBER(S)
# 45                      9.       DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION
# 46                                                   10.     DATE OF REVISION OF THE TEXT
# 47                                                 1.       NAME OF THE MEDICINAL PRODUCT
# 48                                      2.       QUALITATIVE AND QUANTITATIVE COMPOSITION
# 49                                                            Excipient with known effect
# 50                                                            Excipient with known effect
# 51                                                            Excipient with known effect
# 52                                                           3.       PHARMACEUTICAL FORM
# 53                                                          4.       CLINICAL PARTICULARS
# 54                                                        4.1     Therapeutic indications
# 55                                          4.2     Posology and method of administration
# 56                                                                               Posology
# 57                                                                  Paediatric population
# 58                                                            4.3       Contraindications
# 59                                     4.4       Special warnings and precautions for use
# 60                                                                 Paediatric population
# 61  4.5          Interaction with other medicinal products and other forms of interaction
# 62                                                                  Paediatric population
# 63                                           4.6       Fertility, pregnancy and lactation
# 64                                                                              Pregnancy
# 65                                                                         Breast‑feeding
# 66                                                                              Fertility
# 67                                   4.7     Effects on ability to drive and use machines
# 68                                                            4.8     Undesirable effects
# 69                                                                  Paediatric population
# 70                                               Reporting of suspected adverse reactions
# 71                                                                     4.9       Overdose
# 72                                                    5.       PHARMACOLOGICAL PROPERTIES
# 73                                                5.1          Pharmacodynamic properties
# 74                                                                    Mechanism of action
# 75                                                                Pharmacodynamic effects
# 76                                                           Clinical efficacy and safety
# 77                                                                  Paediatric population
# 78                                                   5.2       Pharmacokinetic properties
# 79                                                                             Absorption
# 80                                                                           Distribution
# 81                                                                      Biotransformation
# 82                                                                            Elimination
# 83                                                                Linearity/non‑linearity
# 84                                                        5.3     Preclinical safety data
# 85                                                    6.       PHARMACEUTICAL PARTICULARS
# 86                                                             6.1     List of excipients
# 87                                                              6.2     Incompatibilities
# 88                                                                   6.3       Shelf life
# 89                                                6.4     Special precautions for storage
# 90                                               6.5     Nature and contents of container
# 91                            6.6     Special precautions for disposal and other handling
# 92                                                7.       MARKETING AUTHORISATION HOLDER
# 93                                             8.       MARKETING AUTHORISATION NUMBER(S)
# 94                      9.       DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION
# 95                                                   10.     DATE OF REVISION OF THE TEXT
#
#     htmlIndex                                htmlId  SubSectionIndex  \
# 0          32  ac7e3cae-7fd6-41b8-94cf-305b41a00e91                0
# 1          37  262cf6cd-c84d-4a28-9a78-0e8b33e28b92                0
# 2          41  28158d1e-d09f-4439-ac89-83421a3e2a01                0
# 3          48  0ca8dd99-daba-438a-af65-4eff08b3dee2                0
# 4          55  2f49d824-a6d1-44e3-b63d-ced3e2e38206                0
# 5          57  f53350f9-dd9f-43aa-8fce-3bb31ea4e162                0
# 6          66  56c56365-b661-49cc-b5d6-4f5d7ecc3926                0
# 7          70  60d0bd00-3cc5-4a1d-9c94-06e664136333                0
# 8         116  6388a71b-ea71-4fe4-adc5-40c00ed05119                0
# 9         136  a60cdbf4-c466-47b6-ae62-b70df6747299                0
# 10        140  d3c787f8-5580-4e5a-ae51-449bdce27ba9                0
# 11        184  8ff70ba6-59f4-4789-828e-452d0219d0f0                0
# 12        196  2de52f72-948f-42e3-a02f-c4ac79e22cd3                0
# 13        244  8c2f3f58-67cf-4def-bde8-274736dc6c03                0
# 14        248  9eb79b13-39cf-418b-a544-d83e02130ac2                0
# 15        250  03514c9b-850e-4476-840a-299c1f1073f7                0
# 16        254  4a1cfa33-6f10-455f-9f01-14572ea8915f                0
# 17        258  b9814177-b013-4c0f-a67c-0ea8a9ce374d                0
# 18        262  0a17505b-d97b-4d43-aa14-2ab4fa92f949                0
# 19        266  44310988-aabb-425e-9366-d4aefad212e5                0
# 20        307  f9d7621e-4227-4102-80cf-760cb2bef029                0
# 21        318  e5aabc22-46e0-47ff-b065-c83978195b49                0
# 22        322  9d802a20-0f4e-4c2d-9e09-e3c644ae6490                0
# 23        327  0ed3fea0-8c2f-49f7-b71a-9480e1dc96f2                0
# 24        329  ed870196-6128-4875-83a7-c24d8e71aec1                0
# 25        333  32530418-b5d1-4342-a6a4-57aca04f4c97                0
# 26        339  c4686837-1199-4169-aef2-9469b8a35d27                0
# 27        360  875bed24-c8d7-4039-bf1a-0d09e031e253                0
# 28        453  2ba3e09c-a371-4c5d-bfd4-7c1c0bde37ba                0
# 29        457  ecf0fd19-8a0e-4a49-ac22-b7ad4a2c7f04                0
# 30        463  0f1e951c-68f1-416a-8bb0-5dfa0f609209                0
# 31        469  99852acf-c8f8-4dc6-bec4-80166e2040cd                0
# 32        473  c070d5e5-0ace-4439-b791-d94da3a08d8c                0
# 33        479  f719a6c2-fbbf-4556-baa7-3551a46869b2                0
# 34        483  492d290e-c397-41d7-8549-7dc0b70ca672                0
# 35        533  d6c2bb55-1a6e-4930-9f82-04ed156d68f9                0
# 36        550  001b38b6-f97e-464a-969a-9b5e98bb7e81                0
# 37        552  cc764acb-723a-4589-b086-89a74db16175                0
# 38        580  69385834-27d8-47d6-93b4-4008f5129d8f                0
# 39        584  43701e7c-d0ea-4ac1-904a-611cd60cb588                0
# 40        588  bc91e715-a3b1-4b11-b2fd-4577011db741                0
# 41        592  d6d1066b-4e10-446b-b1a3-6a48e073222b                0
# 42        603  23f5a374-0ced-4930-bbc2-e8363bef311e                0
# 43        608  30214e5b-edd7-41be-9948-0c4cf76dc564                0
# 44        616  00b99946-e8e7-4bad-b1ba-47dbacab188d                0
# 45        623  1c989738-0572-4dd9-a316-ef5ecf6ffe7b                0
# 46        629  490ee2dd-ecd0-4df4-9681-fa1c6f01aaa7                0
# 47        637  85c8a3cc-555f-4cce-8e47-dd3b1291c694                1
# 48        644  09b8ee1c-90a3-4f4a-b212-b6336fe0ce08                1
# 49        650  671f1bea-03c1-4e9b-95be-56efca03a5af                1
# 50        658  78633825-dae4-4941-89d0-edb8869b6cbc                1
# 51        666  f6c07a75-6f7d-444b-9a18-14960a71fba3                1
# 52        673  b1b64bb0-2f71-47ac-b61a-450c5f5b4699                1
# 53        680  3b0711c3-8224-409e-ade1-d57b2c26e51b                1
# 54        682  048e10b5-11a2-4bcf-aa61-1033786702dc                1
# 55        686  96835ecf-9a08-4804-baf9-f5b6ee10ccff                1
# 56        690  1680ace7-79f6-435c-a761-d1b3d64f9113                1
# 57        722  feb3e591-835b-43f9-ac13-cc120d9f4cd6                1
# 58        738  b83e1e31-df61-4eab-b47a-f7cbb8326737                1
# 59        742  7b3b1cde-352b-40e7-89a0-2074c20c0969                1
# 60        778  81d7636d-856b-4e03-921d-a726b2f80696                1
# 61        790  e3223835-8da8-450a-9460-f7696b6661f9                1
# 62        838  c754b935-68cb-4c49-81ea-3691eb88aed9                1
# 63        842  7307e75c-0400-4b09-871f-2f5f12e9eac5                1
# 64        844  5023c1e6-644e-4802-a9c3-036497cf3e1f                1
# 65        848  a10a560f-813f-4272-a9a6-8334b456dbe8                1
# 66        852  72be6957-9a5b-4275-9df2-bbbca320b508                1
# 67        856  661a3574-4e7e-4f7f-9087-4a40bbcbb893                1
# 68        860  1b2f78ce-23cd-4617-8ae3-bdb8c860ae8e                1
# 69        887  bbd9a538-f8a1-4eda-9616-22266a30bc95                1
# 70        898  2d778246-b7c7-4e50-b656-b08f37053478                1
# 71        902  bede07a1-790b-49fd-8acb-29480570f025                1
# 72        907  13bfbbf0-3eea-4c46-981a-456a9cbebb34                1
# 73        909  461bf6e7-b082-4b77-91db-3817357eb288                1
# 74        913  4737e5f5-293f-4d0b-8903-17e79c67186e                1
# 75        919  4672aa32-ec56-43d0-84ea-19273899f329                1
# 76        931  e28aad52-fdb8-4b68-966f-314feb853760                1
# 77       1041  91eda682-6abd-499a-ab80-ffffb50840d6                1
# 78       1045  a186e205-ea7a-4922-a6dc-871f7585b798                1
# 79       1051  ef2ebc62-f4e0-4a27-a9ef-0f876798769b                1
# 80       1057  c938f11b-a074-43d0-8a5d-4154a6f9c89f                1
# 81       1061  1d2cb6ac-3858-463f-9020-16a4ef07363c                1
# 82       1067  f72e3132-cd20-42be-99a8-200ad2c9d9d2                1
# 83       1071  bd2fc13f-b6b1-4ffc-af8e-b5d1db860830                1
# 84       1112  50c72bbb-1fa5-4ab8-bc2d-28730abf108c                1
# 85       1129  ab165f91-ed7c-4be4-a27f-0778306670fe                1
# 86       1131  72820543-c779-46dc-9474-23c439e98901                1
# 87       1142  dd94d86e-6f1e-4b39-ab1a-ba92bdc55053                1
# 88       1146  74901738-61ed-4368-bc58-a98d517abe25                1
# 89       1152  0ffdf38a-3796-401a-9b6f-5ee9b233a8fd                1
# 90       1156  cb090a6b-fa2d-4fd8-952b-f3f88cbd9911                1
# 91       1162  9cdd16ee-87df-4752-aebc-46430aeecbe4                1
# 92       1167  955c110c-99e9-43d7-8f6b-6567271566a0                1
# 93       1175  503c5718-3c9f-45e2-9c18-c36bfab2a3a1                1
# 94       1182  8f67a9e9-1e22-4b5f-ba8f-ba0f72cd704c                1
# 95       1188  d6999caf-45fa-4700-b2d8-cebc1e2629e7                1
#
#    doc_parent_id  \
# 0
# 1          20003
# 2          20004
# 3          20004
# 4          20008
# 5          20009
# 6          20009
# 7          20011
# 8          20012
# 9          20009
# 10         20009
# 11         20017
# 12         20009
# 13         20020
# 14         20009
# 15         20022
# 16         20022
# 17         20022
# 18         20009
# 19         20009
# 20         20027
# 21         20027
# 22         20009
# 23         20030
# 24         20032
# 25         20033
# 26         20033
# 27         20033
# 28         20033
# 29         20032
# 30         20038
# 31         20038
# 32         20038
# 33         20038
# 34         20038
# 35         20032
# 36         20045
# 37         20047
# 38         20047
# 39         20047
# 40         20047
# 41         20047
# 42         20047
# 43         20053
# 44         20055
# 45         20056
# 46         20057
# 47
# 48         20003
# 49         20004
# 50         20004
# 51         20004
# 52         20004
# 53         20008
# 54         20009
# 55         20009
# 56         20011
# 57         20012
# 58         20009
# 59         20009
# 60         20017
# 61         20009
# 62         20020
# 63         20009
# 64         20022
# 65         20022
# 66         20022
# 67         20009
# 68         20009
# 69         20027
# 70         20027
# 71         20009
# 72         20030
# 73         20032
# 74         20033
# 75         20033
# 76         20033
# 77         20033
# 78         20032
# 79         20038
# 80         20038
# 81         20038
# 82         20038
# 83         20038
# 84         20032
# 85         20045
# 86         20047
# 87         20047
# 88         20047
# 89         20047
# 90         20047
# 91         20047
# 92         20053
# 93         20055
# 94         20056
# 95         20057
#
#                                                                                                                                                                                                        Text  \
# 0                                                                                                                    \n1.       NAME OF THE MEDICINAL PRODUCT\n \nKalydeco 150 mg film‑coated tablets\n \n
# 1                                                                                          \n2.       QUALITATIVE AND QUANTITATIVE COMPOSITION\n \nEach film‑coated tablet contains 150 mg of ivacaftor.\n
# 2                                           \nExcipient with known effect\n \nEach film‑coated tablet contains 167.2 mg of lactose monohydrate.\n \nFor the full list of excipients, see section 6.1.\n \n
# 3   \n3.       PHARMACEUTICAL FORM\n \nFilm‑coated tablet (tablet)\n \nLight blue, capsule‑shaped film‑coated tablets, printed with “V 150” in black ink on one side and plain on the other (16.5 mm x 8...
# 4                                                                                                                                                                        \n4.       CLINICAL PARTICULARS\n
# 5   \n4.1     Therapeutic indications\n \nKalydeco tablets are indicated: \n·         As monotherapy for the treatment of adults, adolescents, and children aged 6 years and older and weighing 25 kg or...
# 6   \n4.2     Posology and method of administration\n \nKalydeco should only be prescribed by physicians with experience in the treatment of cystic fibrosis. If the patient's genotype is unknown, an a...
# 7   \nPosology\n \nAdults, adolescents and children aged 6 years and older should be dosed according to Table 1. \n \nTable 1: Dosing recommendations\n       Morning   Evening     Ivacaftor as monothe...
# 8   \nPaediatric population\n \nThe safety and efficacy of ivacaftor monotherapy in children aged less than 4 months have not been established. No data are available.\n \nAn appropriate dose for child...
# 9                                                                          \n4.3       Contraindications\n \nHypersensitivity to the active substance or to any of the excipients listed in section 6.1.\n
# 10  \n4.4       Special warnings and precautions for use\n \nOnly patients with CF who had a G551D, G1244E, G1349D, G178R, G551S, S1251N, S1255P, S549N, S549R gating (class III), G970R or R117H mutati...
# 11  \nPaediatric population\n \nCases of non‑congenital lens opacities/cataracts without impact on vision have been reported in paediatric patients treated with ivacaftor and ivacaftor-containing regi...
# 12  \n4.5          Interaction with other medicinal products and other forms of interaction\n \nIvacaftor is a substrate of CYP3A4 and CYP3A5. It is a weak inhibitor of CYP3A and P‑gp and a potential ...
# 13                                                                                                                   \nPaediatric population\n \nInteraction studies have only been performed in adults.\n
# 14                                                                                                                                                           \n4.6    Fertility, pregnancy and lactation\n
# 15  \nPregnancy\n \nThere are no or limited amount of data (less than 300 pregnancy outcomes) from the use of ivacaftor in pregnant women. Animals studies do not indicate direct or indirect harmful ef...
# 16  \nBreast‑feeding\n \nIt is unknown whether ivacaftor and/or its metabolites are excreted in human milk. Available pharmacokinetic data in animals have shown excretion of ivacaftor into the milk of...
# 17                                        \nFertility\n \nThere are no data available on the effect of ivacaftor on fertility in humans. Ivacaftor had an effect on fertility in rats (see section 5.3).\n
# 18  \n4.7     Effects on ability to drive and use machines\n \nIvacaftor has minor influence on the ability to drive or use machines. Ivacaftor may cause dizziness (see section 4.8) and, therefore, pa...
# 19  \n4.8     Undesirable effects\n \nSummary of the safety profile\n \nThe most common adverse reactions experienced by patients aged 6 years and older who received ivacaftor are headache (23.9%), or...
# 20  \nPaediatric population\n \nThe safety data of ivacaftor as monotherapy were evaluated in 6 patients between 4 months to less than 6 months of age, 11 patients between 6 months to less than 12 mon...
# 21  \nReporting of suspected adverse reactions\n \nReporting suspected adverse reactions after authorisation of the medicinal product is important. It allows continued monitoring of the benefit/risk b...
# 22  \n4.9       Overdose\n \nNo specific antidote is available for overdose with ivacaftor. Treatment of overdose consists of general supportive measures including monitoring of vital signs, liver fun...
# 23                                                                                                                                                                 \n5.       PHARMACOLOGICAL PROPERTIES\n
# 24                                                                         \n5.1          Pharmacodynamic properties\n \nPharmacotherapeutic group: Other respiratory system products, ATC code: R07AX02\n
# 25  \nMechanism of action\n \nIvacaftor is a potentiator of the CFTR protein, i.e., in vitro ivacaftor increases CFTR channel gating to enhance chloride transport in specified gating mutations (as lis...
# 26  \nPharmacodynamic effects\n \nIvacaftor as monotherapy\n \nIn studies 1 and 2 in patients with the G551D mutation in one allele of the CFTR gene, ivacaftor led to rapid (15 days), substantial (the...
# 27  \nClinical efficacy and safety\n \nIvacaftor as monotherapy\n \nStudy 1 and 2: studies in patients with CF with G551D gating mutations\n \nThe efficacy of ivacaftor has been evaluated in two phase...
# 28  \nPaediatric population\n \nThe European Medicines Agency has deferred the obligation to submit the results of studies with Kalydeco in one or more subsets of the paediatric population in cystic f...
# 29  \n5.2     Pharmacokinetic properties\n \nThe pharmacokinetics of ivacaftor are similar between healthy adult volunteers and patients with CF.\n \nAfter oral administration of a single 150 mg dose ...
# 30  \nAbsorption\n \nFollowing multiple oral dose administrations of ivacaftor, the exposure of ivacaftor generally increased with dose from 25 mg every 12 hours to 450 mg every 12 hours. When given w...
# 31  \nDistribution\n \nIvacaftor is approximately 99% bound to plasma proteins, primarily to alpha 1‑acid glycoprotein and albumin. Ivacaftor does not bind to human red blood cells. After oral adminis...
# 32  \nBiotransformation\n \nIvacaftor is extensively metabolised in humans. In vitro and in vivo data indicate that ivacaftor is primarily metabolised by CYP3A. M1 and M6 are the two major metabolites...
# 33  \nElimination\n \nFollowing oral administration in healthy volunteers, the majority of ivacaftor (87.8%) was eliminated in the faeces after metabolic conversion. The major metabolites M1 and M6 ac...
# 34  \nLinearity/non‑linearity\n \nThe pharmacokinetics of ivacaftor are generally linear with respect to time or dose ranging from 25 mg to 250 mg.\n \nSpecial populations\n \nHepatic impairment\n \nF...
# 35  \n5.3     Preclinical safety data\n \nNon-clinical data reveal no special hazard for humans based on conventional studies of safety pharmacology, repeated dose toxicity, genotoxicity, and carcinog...
# 36                                                                                                                                                                 \n6.       PHARMACEUTICAL PARTICULARS\n
# 37  \n6.1     List of excipients\n \nTablet core\n \nCellulose, microcrystalline\nLactose monohydrate\nHypromellose acetate succinate\nCroscarmellose sodium\nSodium laurilsulfate (E487)\nSilica, collo...
# 38                                                                                                                                                       \n6.2     Incompatibilities\n \nNot applicable.\n
# 39                                                                                                                                                                     \n6.3     Shelf life\n \n4 years.\n
# 40                                                                                 \n6.4     Special precautions for storage\n \nThis medicinal product does not require any special storage conditions.\n
# 41  \n6.5     Nature and contents of container\n \nThe film-coated tablets are packed in a thermoform (PolyChloroTriFluoroEthylene [PCTFE]/foil) blister or a High-Density PolyEthylene (HDPE) bottle wi...
# 42                       \n6.6    Special precautions for disposal and other handling\n \nAny unused medicinal product or waste material should be disposed of in accordance with local requirements.\n \n
# 43                                                   \n7.       MARKETING AUTHORISATION HOLDER\n \nVertex Pharmaceuticals (Ireland) Limited\n28-32 Pembroke Street Upper\nDublin 2, D02 EK84\nIreland\n \n
# 44                                                                                                 \n8.       MARKETING AUTHORISATION NUMBER(S)\n \nEU/1/12/782/001\nEU/1/12/782/002\nEU/1/12/782/005\n \n
# 45                                           \n9.       DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION\n \nDate of first authorisation: 23 July 2012\nDate of latest renewal: 28 April 2017\n \n
# 46            \n10.     DATE OF REVISION OF THE TEXT\n \nDetailed information on this medicinal product is available on the website of the European Medicines Agency http://www.ema.europa.eu.\n\n \n\n \n
# 47                                               \n1.       NAME OF THE MEDICINAL PRODUCT\n \nKalydeco 25 mg granules in sachet\nKalydeco 50 mg granules in sachet\nKalydeco 75 mg granules in sachet\n \n
# 48                                                                \n2.       QUALITATIVE AND QUANTITATIVE COMPOSITION\n \nKalydeco 25 mg granules in sachet\n \nEach sachet contains 25 mg of ivacaftor.\n
# 49                             \nExcipient with known effect\n \nEach sachet contains 36.6 mg of lactose monohydrate.\n \nKalydeco 50 mg granules in sachet\n \nEach sachet contains 50 mg of ivacaftor.\n
# 50                             \nExcipient with known effect\n \nEach sachet contains 73.2 mg of lactose monohydrate.\n \nKalydeco 75 mg granules in sachet\n \nEach sachet contains 75 mg of ivacaftor.\n
# 51                                                      \nExcipient with known effect\n \nEach sachet contains 109.8 mg of lactose monohydrate.\n \nFor the full list of excipients, see section 6.1.\n \n
# 52                                                                              \n3.       PHARMACEUTICAL FORM\n \nGranules in sachet\n \nWhite to off‑white granules approximately 2 mm in diameter.\n \n
# 53                                                                                                                                                                       \n4.       CLINICAL PARTICULARS\n
# 54  \n4.1     Therapeutic indications\n \nKalydeco granules are indicated for the treatment of infants aged at least 4 months, toddlers and children weighing 5 kg to less than 25 kg with cystic fibros...
# 55  \n4.2     Posology and method of administration\n \nKalydeco should only be prescribed by physicians with experience in the treatment of cystic fibrosis. If the patient's genotype is unknown, an a...
# 56  \nPosology\n \nInfants aged at least 4 months, toddlers, children, adolescents and adults should be dosed according to Table 1.\n \nTable 1: Dosing recommendations for patients aged 4 months and o...
# 57  \nPaediatric population\n \nThe safety and efficacy of ivacaftor in children aged less than 4 months have not been established. No data are available.\n \nLimited data are available in patients le...
# 58                                                                         \n4.3       Contraindications\n \nHypersensitivity to the active substance or to any of the excipients listed in section 6.1.\n
# 59  \n4.4       Special warnings and precautions for use\n \nOnly patients with CF who had a G551D, G1244E, G1349D, G178R, G551S, S1251N, S1255P, S549N or S549R gating (class III) or G970R mutation in...
# 60  \nPaediatric population \n \nCases of non‑congenital lens opacities/cataracts without impact on vision have been reported in paediatric patients treated with ivacaftor. Although other risk factors...
# 61  \n4.5          Interaction with other medicinal products and other forms of interaction\n \nIvacaftor is a substrate of CYP3A4 and CYP3A5. It is a weak inhibitor of CYP3A and P‑gp and a potential ...
# 62                                                                                                                  \nPaediatric population\n \nInteraction studies have only been performed in adults. \n
# ...
# 19  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">4.8     <a name="_Hlk36070162">Undesirable effects</a></span></b></p><p class="labeltext" style="page-b...
# 20  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Paediatric population</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avo...
# 21  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Reporting of suspected adverse reactions</span></u></p><p class="MsoNormal" style="line-height:normal;p...
# 22  <h2 style="margin:0in"><span lang="EN-GB" style="font-size:11.0pt">4.9       Overdose</span></h2><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><span lang="EN-GB"> </span><...
# 23  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>5.       PHARMACOLOGICAL PROPERTIES</span></h1><p class="MsoNormal" style...
# 24  <p class="MsoNormal" style="margin-left:28.5pt;text-indent:-28.5pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">5.1<span style='font:7.0pt "Times New Roman"'>          </span>...
# 25  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Mechanism of action</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avoid...
# 26  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Pharmacodynamic effects</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:a...
# 27  <p class="documenttext" style="margin-bottom:0in;page-break-after:avoid"><u><span lang="EN-GB" style="font-size:11.0pt">Clinical efficacy and safety</span></u></p><p class="documenttext" style="ma...
# 28  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Paediatric population</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avo...
# 29  <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">5.2     Pharmacokinetic properties</span></b></p><p class="Ms...
# 30  <p class="labeltextheading"><u><span lang="EN-GB" style="font-size:11.0pt; font-style:normal">Absorption</span></u></p><p class="labeltextheading"><u><span lang="EN-GB" style="font-size:11.0pt; fo...
# 31  <p class="MsoNormal" style="margin-right:-.1pt;line-height:normal;page-break-after: avoid"><u><span lang="EN-GB">Distribution</span></u></p><p class="MsoNormal" style="margin-right:-.1pt;line-heig...
# 32  <p class="labeltext" style="page-break-after:avoid"><u><span lang="EN-GB" style="font-size:11.0pt">Biotransformation</span></u></p><p class="labeltext" style="page-break-after:avoid"><i><u><span l...
# 33  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Elimination</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><sp...
# 34  <p class="labeltext" style="page-break-after:avoid"><u><span lang="EN-GB" style="font-size:11.0pt">Linearity/non‑linearity</span></u></p><p class="labeltext" style="page-break-after:avoid"><u><spa...
# 35  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">5.3     Preclinical safety data</span></b></p><p class="MsoNormal" style="line-height:normal;page-break...
# 36  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>6.       PHARMACEUTICAL PARTICULARS</span></h1><p class="MsoNormal" style...
# 37  <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">6.1     List of excipients</span></b></p><p class="MsoNormal"...
# 38  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">6.2     Incompatibilities</span></b></p><p class="MsoNormal" style="line-height:normal;page-break-after...
# 39  <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">6.3     Shelf life</span></b></p><p class="MsoNormal" style="...
# 40  <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">6.4     Special precautions for storage</span></b></p><p clas...
# 41  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">6.5     Nature and contents of container</span></b></p><p class="MsoNormal" style="line-height:normal;p...
# 42  <p class="MsoNormal" style="margin-left:28.1pt;text-indent:-28.1pt;line-height: normal;page-break-after:avoid"><a name="OLE_LINK1"><b><span lang="EN-GB">6.6    Special precautions for disposal and...
# 43  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>7.       MARKETING AUTHORISATION HOLDER</span></h1><p class="MsoNormal" s...
# 44  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>8.       MARKETING AUTHORISATION NUMBER(S)</span></h1><p class="MsoNormal...
# 45  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>9.       DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION</span><...
# 46  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>10.     DATE OF REVISION OF THE TEXT</span></h1><p class="MsoNormal" styl...
# 47  <p class="MsoNormal" style="line-height:normal"><b><span lang="EN-GB">1.       NAME OF THE MEDICINAL PRODUCT</span></b></p><p class="MsoNormal" style="line-height:normal"><span lang="EN-GB"> </spa...
# 48  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>2.       QUALITATIVE AND QUANTITATIVE COMPOSITION</span></h1><p class="Ms...
# 49  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><i><span lang="EN-GB">Excipient with known effect</span></i></p><p class="MsoNormal" style="line-height:normal;page-break-aft...
# 50  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><i><span lang="EN-GB">Excipient with known effect</span></i></p><p class="MsoNormal" style="line-height:normal;page-break-aft...
# 51  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><i><span lang="EN-GB">Excipient with known effect</span></i></p><p class="MsoNormal" style="line-height:normal;page-break-aft...
# 52  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>3.       PHARMACEUTICAL FORM</span></h1><p class="MsoNormal" style="text-...
# 53  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif;text-transform:uppercase'>4.       </span><span lang="EN-GB" style='font-s...
# 54  <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">4.1     Therapeutic indications</span></b></p><p class="MsoNo...
# 55  <p class="MsoNormal" style="line-height:normal"><b><span lang="EN-GB">4.2     Posology and method of administration</span></b></p><p class="MsoNormal" style="line-height:normal"><span lang="EN-GB"...
# 56  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Posology</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><span lan...
# 57  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Paediatric population</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avo...
# 58  <h2 style="margin:0in"><span lang="EN-GB" style="font-size:11.0pt">4.3       Contraindications</span></h2><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><span lang="EN-GB">...
# 59  <h2 style="margin:0in"><span lang="EN-GB" style="font-size:11.0pt">4.4       Special warnings and precautions for use</span></h2><p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35p...
# 60  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Paediatric population </span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:av...
# 61  <p class="MsoNormal" style="margin-left:28.5pt;text-indent:-28.5pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">4.5<span style='font:7.0pt "Times New Roman"'>          </span>...
# 62  <p style="margin:0in;page-break-after:avoid"><u><span lang="EN-GB" style="font-size:11.0pt">Paediatric population</span></u></p><p style="margin:0in;page-break-after:avoid"><u><span lang="EN-GB" s...
# 63  <h2 style="margin:0in"><span lang="EN-GB" style="font-size:11.0pt">4.6       Fertility, pregnancy and lactation</span></h2><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><s...
# 64  <p class="labeltext" style="page-break-after:avoid"><u><span style="font-size: 11.0pt">Pregnancy</span></u></p><p class="labeltext" style="page-break-after:avoid"><u><span style="font-size: 11.0pt...
# 65  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Breast‑feeding</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u>...
# 66  <p class="MsoNormalIndent" style="margin:0in;page-break-after:avoid"><u><span lang="EN-GB">Fertility</span></u></p><p class="MsoNormalIndent" style="margin:0in;page-break-after:avoid"><u><span lan...
# 67  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">4.7     Effects on ability to drive and use machines</span></b></p><p class="MsoNormal" style="line-hei...
# 68  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">4.8     Undesirable effects</span></b></p><p class="labeltext" style="page-break-after:avoid"><u><span ...
# 69  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Paediatric population</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avo...
# 70  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Reporting of suspected adverse reactions</span></u></p><p class="MsoNormal" style="line-height:normal;p...
# 71  <h2 style="margin:0in"><span lang="EN-GB" style="font-size:11.0pt">4.9       Overdose</span></h2><p class="labeltext" style="page-break-after:avoid"><span style="font-size:11.0pt"> </span></p><p c...
# 72  <h1 style="margin:0in"><span lang="EN-GB" style='font-size:11.0pt;font-family: "Times New Roman",serif'>5.       PHARMACOLOGICAL PROPERTIES</span></h1><p class="MsoNormal" style="line-height:norma...
# 73  <p class="MsoNormal" style="margin-left:28.5pt;text-indent:-28.5pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">5.1<span style='font:7.0pt "Times New Roman"'>          </span>...
# 74  <p class="MsoNormal" style="margin-right:-.1pt;line-height:normal;page-break-after: avoid"><u><span lang="EN-GB">Mechanism of action</span></u></p><p class="MsoNormal" style="margin-right:-.1pt;li...
# 75  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Pharmacodynamic effects</span></u></p><p class="MsoNormal" style="page-break-after:avoid"><i><span lang...
# 76  <p class="MsoNormal" style="page-break-after:avoid"><u><span lang="EN-GB">Clinical efficacy and safety</span></u></p><p class="MsoNormal" style="page-break-after:avoid"><u><span lang="EN-GB"><span...
# 77  <p class="MsoNormal" style="line-height:normal"><u><span lang="EN-GB">Paediatric population</span></u></p><p class="MsoNormal" style="line-height:normal"><u><span lang="EN-GB"><span style="text-de...
# 78  <h2 style="margin:0in"><span lang="EN-GB" style="font-size:11.0pt">5.2       Pharmacokinetic properties</span></h2><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><span lang...
# 79  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Absorption</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><spa...
# 80  <p class="MsoNormal" style="margin-right:-.1pt;line-height:normal;page-break-after: avoid"><u><span lang="EN-GB">Distribution</span></u></p><p class="MsoNormal" style="margin-right:-.1pt;line-heig...
# 81  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Biotransformation</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avoid">...
# 82  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Elimination</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><sp...
# 83  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><u><span lang="EN-GB">Linearity/non‑linearity</span></u></p><p class="MsoNormal" style="line-height:normal;page-break-after:a...
# 84  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">5.3     Preclinical safety data</span></b></p><p class="MsoNormal" style="line-height:normal;page-break...
# 85  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>6.       PHARMACEUTICAL PARTICULARS</span></h1><p class="MsoNormal" style...
# 86  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">6.1     List of excipients</span></b></p><p class="MsoNormal" style="line-height:normal;page-break-afte...
# 87  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">6.2     Incompatibilities</span></b></p><p class="MsoNormal" style="line-height:normal;page-break-after...
# 88  <h2 style="margin:0in"><span lang="EN-GB" style="font-size:11.0pt">6.3       Shelf life</span></h2><p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><span lang="EN-GB"> </span...
# 89  <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">6.4     Special precautions for storage</span></b></p><p clas...
# 90  <p class="MsoNormal" style="line-height:normal;page-break-after:avoid"><b><span lang="EN-GB">6.5     Nature and contents of container</span></b></p><p class="MsoNormal" style="line-height:normal;p...
# 91  <p class="MsoNormal" style="margin-left:28.35pt;text-indent:-28.35pt;line-height: normal;page-break-after:avoid"><b><span lang="EN-GB">6.6     Special precautions for disposal and other handling</...
# 92  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>7.       MARKETING AUTHORISATION HOLDER</span></h1><p class="MsoNormal" s...
# 93  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>8.       MARKETING AUTHORISATION NUMBER(S)</span></h1><p class="MsoNormal...
# 94  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>9.       DATE OF FIRST AUTHORISATION/RENEWAL OF THE AUTHORISATION</span><...
# 95  <h1 style="margin:0in;line-height:normal"><span lang="EN-GB" style='font-size: 11.0pt;font-family:"Times New Roman",serif'>10.     DATE OF REVISION OF THE TEXT</span></h1><p class="MsoNormal" styl...

# %%
    documentAnnotationObj = DocumentAnnotation('Kalydeco II-86-PI-clean_SmPC.json','c270d6ccaf9e47e9b20b322e2383c4ba','https://spor-uat.azure-api.net/pms/api/v2/',df,coll)
    pms_oms_annotation_data = documentAnnotationObj.processRegulatedAuthorizationForDoc(['EU/2/10/106/006','EU/2/09/098/001'])
# Out:
# EU/2/10/106/006
# Found entry with code 220000000061
# ['LOC-100010489', '600000033247']
# Bovilis BTV8 (--) - Suspension for injection
# EU/2/09/098/001
# Found entry with code 220000000061
# ['0', '600000035065']
# Melovem 5 mg/ml  - Solution for injection

# %% [markdown]
# # XML Generation Stage

# %%
xmlLogger = loggerCreator('XmlGeneration_'+ getRandomString(1))
fhirXmlGeneratorObj = FhirXmlGenerator(xmlLogger, pms_oms_annotation_data)
generated_xml = fhirXmlGeneratorObj.generateXml(dfExtractedHierRR,  'Kalydeco II-86-PI-clean_SmPC.xml')
# Out:
# 2021-04-28 13:53:55,991 : XmlGeneration_L : Initiating XML Generation
# DEBUG:XmlGeneration_L:Initiating XML Generation
# 2021-04-28 13:53:56,017 : XmlGeneration_L : Writing to File:Kalydeco II-86-PI-clean_SmPC.xml
# INFO:XmlGeneration_L:Writing to File:Kalydeco II-86-PI-clean_SmPC.xml

# %%
fhirServiceObj =  FhirService(generated_xml)
fhirServiceObj.submitFhirXml()
# Out:
# POST sucessful: XML added with id abf232f9-7786-48d5-ad9f-4c581520af29
