# %%
import os
import zipfile
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import tracemalloc
import psutil
import pprint
import pandas as pd
import uuid
import json
import os
import glob
import re
import sys
from bs4 import NavigableString, BeautifulSoup
from collections import defaultdict
import random
import string
import time

from utils.config import config
from utils.logger.logger import loggerCreator

# ePI Modules
from parse.rulebook.rulebook import StyleRulesDictionary

from parse.extractor.parser import parserExtractor
from match.matchDocument.matchDocument import MatchDocument
from documentAnnotation.documentAnnotation import DocumentAnnotation
from htmlDocTypePartitioner.partition import DocTypePartitioner
from extractContentBetweenHeadings.dataBetweenHeadingsExtractor import DataBetweenHeadingsExtractor
from fhirXmlGenerator.fhirXmlGenerator import FhirXmlGenerator
from fhirService.fhirService import FhirService
from utils.logger.matchLogger import MatchLogger
from languageInfo.documentTypeNames.documentTypeNames import DocumentTypeNames


class FolderNotFoundError(Exception):
    pass

class Metrics:
    
    def __init__(self, logFileName, logger):
        self.logFileName = logFileName
        self.start()
        self.writer = open(self.logFileName, 'a')
        self.writer.write("StepName,Time,Current Memory,Peak Memory,Used Ram Percentage\n")
        self.finalPeak = 0
        self.finalTotalTime = 0
        self.finalUsedRamPerc = 0
        self.logger = logger
    
    def start(self):
        self.startTime = time.time()
        tracemalloc.start()
    
    def getMetric(self, msg):
        
        self.endTime = time.time()
        
        self.totalTime = self.endTime - self.startTime
        
        
        current, peak = tracemalloc.get_traced_memory()
        current = current / 10**6
        peak = peak / 10**6
        
        usedRamPerc = psutil.virtual_memory()[2]
        
        self.finalPeak = max(self.finalPeak, peak)
        self.finalUsedRamPerc = max(self.finalUsedRamPerc, usedRamPerc)

        self.finalTotalTime = self.finalTotalTime + self.totalTime
        #self.finalTotalTime = round(self.finalTotalTime/60,3)
        
        outputString = f"{msg},{round(self.totalTime/60,4)} Min,{current} MB,{peak} MB,{usedRamPerc}%\n"
        
        self.logger.logFlowCheckpoint(f"{outputString}")
        
        print(f"Metrics : {outputString}")
        self.writer.write(outputString)
        tracemalloc.stop()
        tracemalloc.start()
        self.startTime = time.time()
    def end(self):
        
        current, peak = tracemalloc.get_traced_memory()
        current = current / 10**6
        outputString = f"Final Metrics,{round(self.finalTotalTime/60,4)} Min,{current} MB,{self.finalPeak} MB,{self.finalUsedRamPerc}%\n"
        print(f"Metrics : {outputString}")
        self.logger.logFlowCheckpoint(f"{outputString}")
        self.writer.write(outputString)
        self.writer.close()
        tracemalloc.stop()
        
        


def convertToInt(x):
    try:
        return str(int(x))
    except:
        return x


def convertCollectionToDataFrame(collection):

    dfExtractedHier = pd.DataFrame(collection)
    dfExtractedHier['parent_id'] = dfExtractedHier['parent_id'].apply(
        lambda x: convertToInt(x))
    dfExtractedHier['id'] = dfExtractedHier['id'].apply(
        lambda x: convertToInt(x))

    return dfExtractedHier

def getRandomString(N):
    str_ = ''.join(random.choice(string.ascii_uppercase + string.digits
                                 + string.ascii_lowercase) for _ in range(N))
    return str_


def convertHtmlToJson(controlBasePath, basePath, domain, procedureType, languageCode, htmlDocName, fileNameQrd, fileNameLog):

    module_path = os.path.join(basePath)

    if "/" in basePath:
        pathSep = "/"
    else:
        pathSep = "\\"
    
    # Generate output folder path
    output_json_path = os.path.join(basePath, 'outputJSON')

    """
        Check if input folder exists, else throw exception
    """
    if(os.path.exists(module_path)):
        filenames = glob.glob(os.path.join(module_path, htmlDocName))

        # Create language specific folder in outputJSON folder if it doesn't exist
        if(not os.path.exists(output_json_path)):
            os.mkdir(output_json_path)
        logger = MatchLogger(f'Parser_{getRandomString(1)}', htmlDocName,
                             domain, procedureType, languageCode, "HTML", fileNameLog)

        styleLogger = MatchLogger(
            f'Style Dictionary_{getRandomString(1)}', htmlDocName, domain, procedureType, languageCode, "HTML", fileNameLog)

        styleRulesObj = StyleRulesDictionary(logger=styleLogger,
                                             controlBasePath=controlBasePath,
                                             language=languageCode,
                                             fileName=fileNameQrd,
                                             domain=domain,
                                             procedureType=procedureType
                                             )

        parserObj = parserExtractor(config, logger, styleRulesObj.styleRuleDict,
                                    styleRulesObj.styleFeatureKeyList,
                                    styleRulesObj.qrd_section_headings)

        for input_filename in filenames:
          # if(input_filename.find('Kalydeco II-86-PI-clean')!=-1):
            output_filename = os.path.join(output_json_path, htmlDocName)
            style_filepath =  output_filename.replace('.html','.txt')
            style_filepath =  style_filepath.replace('.txtl','.txt')
            style_filepath =  style_filepath.replace('.htm','.txt')
            print("-------------",style_filepath,"-----------------")

            output_filename = output_filename.replace('.html', '.json')
            output_filename = output_filename.replace('.htm', '.json')
            print(input_filename, output_filename)
            parserObj.createPIJsonFromHTML(input_filepath=input_filename,
                                           output_filepath=output_filename,
                                           style_filepath = style_filepath,
                                           img_base64_dict=parserObj.convertImgToBase64(input_filename)
                                           )
            
        return output_filename.split(pathSep)[-1], style_filepath
    else:
        try:    
            raise FolderNotFoundError(module_path + " not found")
        except:  
            logger.logFlowCheckpoint("Folder For Language Code Not Found In Input File")
            logger.logException("Folder For Language Code Not Found In Input File")
        raise FolderNotFoundError(module_path + " not found")
        return None


def splitJson(controlBasePath, basePath, domain, procedureType, languageCode, fileNameJson, fileNameQrd, fileNameLog):

    styleLogger = MatchLogger(
        f'Style Dictionary_{getRandomString(1)}', fileNameJson, domain, procedureType, languageCode, "Json", fileNameLog)

    styleRulesObj = StyleRulesDictionary(logger=styleLogger,
                                        controlBasePath=controlBasePath,
                                        language=languageCode,
                                        fileName=fileNameQrd,
                                        domain=domain,
                                        procedureType=procedureType
                                        )
    
    path_json = os.path.join(basePath,'outputJSON', fileNameJson)
    print("PathJson",path_json)
    partitionLogger = MatchLogger(
        f'Partition_{getRandomString(1)}', fileNameJson, domain, procedureType, languageCode, "Json", fileNameLog)

    partitioner = DocTypePartitioner(partitionLogger)

    partitionedJsonPaths = partitioner.partitionHtmls(
        styleRulesObj.qrd_section_headings, path_json)

    return partitionedJsonPaths


def extractAndValidateHeadings(controlBasePath,
                                basePath,
                                domain,
                                procedureType,
                                languageCode,
                                documentNumber,
                                fileNameDoc,
                                fileNameQrd,
                                fileNameMatchRuleBook,
                                fileNameDocumentTypeNames,
                                fileNameLog,
                                stopWordFilterLen=6,
                                isPackageLeaflet=False,
                                medName=None
                                ):

    if documentNumber == 0:
        topHeadingsConsidered = 4
        bottomHeadingsConsidered = 6
    elif documentNumber == 1:
        topHeadingsConsidered = 3
        bottomHeadingsConsidered = 5
    elif documentNumber == 2:
        topHeadingsConsidered = 5
        bottomHeadingsConsidered = 15
    else:
        topHeadingsConsidered = 5
        bottomHeadingsConsidered = 10

    print(f"Starting Heading Extraction For File :- {fileNameDoc}")
    logger = MatchLogger(f"Heading Extraction {fileNameDoc}_{getRandomString(1)}", fileNameDoc, domain, procedureType, languageCode, documentNumber, fileNameLog)
    logger.logFlowCheckpoint("Starting Heading Extraction")

    stopWordlanguage = DocumentTypeNames(
        controlBasePath=controlBasePath,
        fileNameDocumentTypeNames=fileNameDocumentTypeNames,
        languageCode=languageCode,
        domain=domain,
        procedureType=procedureType,
        documentNumber=documentNumber
        ).extractStopWordLanguage()

    matchDocObj = MatchDocument(
        logger,
        controlBasePath,
        basePath,
        domain,
        procedureType,
        languageCode,
        documentNumber,
        fileNameDoc,
        fileNameQrd,
        fileNameMatchRuleBook,
        fileNameDocumentTypeNames,
        topHeadingsConsidered,
        bottomHeadingsConsidered,
        stopWordFilterLen,
        stopWordlanguage,
        isPackageLeaflet,
        medName)
    df, coll, documentType = matchDocObj.matchHtmlHeaddingsWithQrd()

    return df, coll, documentType


def parseDocument(controlBasePath, basePath ,htmlDocName, fileNameQrd, fileNameMatchRuleBook, fileNameDocumentTypeNames, medName = None):
    
    
    if "/" in basePath:
        pathSep = "/"        
    else:
        pathSep = "\\"
    
    fileNameLog = os.path.join(basePath,'FinalLog.txt')

    pathComponents = basePath.split(pathSep)
    print(pathComponents, htmlDocName)
    timestamp = pathComponents[-1]
    languageCode =  pathComponents[-2]
    medName = pathComponents[-3]
    procedureType = pathComponents[-4]
    domain = pathComponents[-5]

    print(timestamp, languageCode, medName, procedureType, domain)
        
    flowLogger =  MatchLogger(f"Flow Logger HTML_{getRandomString(1)}", htmlDocName, domain, procedureType, languageCode, "HTML", fileNameLog)
    
    metrics = Metrics(os.path.join(basePath,'Metrics.csv'),flowLogger)
    
    
    flowLogger.logFlowCheckpoint("Starting HTML Conversion To Json")
    ###Convert Html to Json
    fileNameJson, stylesFilePath = convertHtmlToJson(controlBasePath, basePath, domain, procedureType, languageCode, htmlDocName, fileNameQrd, fileNameLog)
    
    print("stylePath:-",stylesFilePath)
    flowLogger.logFlowCheckpoint("Completed HTML Conversion To Json")
    metrics.getMetric("HTML Conversion To Json")

    flowLogger.logFlowCheckpoint("Starting Json Split")

    ###Split Uber Json to multiple Jsons for each category.
    partitionedJsonPaths = splitJson(controlBasePath, basePath, domain, procedureType, languageCode, fileNameJson, fileNameQrd, fileNameLog)
    
    partitionedJsonPaths = [ path.split(pathSep)[-1] for path in partitionedJsonPaths]
    flowLogger.logFlowCheckpoint(str(partitionedJsonPaths))
    
    flowLogger.logFlowCheckpoint("Completed Json Split")
    metrics.getMetric("Split Json")
    
    flowLogger.logFlowCheckpoint("Started Processing Partitioned Jsons")
    
    for index, fileNamePartitioned in enumerate(partitionedJsonPaths):
        flowLogger.logFlowCheckpoint(f"\n\n\n\n||||||||||||||||||||||||||||||||{str(index)} ||||| {str(fileNamePartitioned)}||||||||||||||||||||||||||||||||\n\n\n\n")
        
        if index == 3:
            stopWordFilterLen = 100
            isPackageLeaflet = True
        else:
            stopWordFilterLen = 6
            isPackageLeaflet = False
            
        df, coll, documentType = extractAndValidateHeadings(controlBasePath,
                                    basePath,
                                    domain,
                                    procedureType,
                                    languageCode,
                                    index,
                                    fileNamePartitioned,
                                    fileNameQrd,
                                    fileNameMatchRuleBook,
                                    fileNameDocumentTypeNames,
                                    fileNameLog,
                                    stopWordFilterLen=stopWordFilterLen,
                                    isPackageLeaflet=isPackageLeaflet,
                                    medName=medName)
        
        
        print(f"Completed Heading Extraction For File")
        flowLogger.logFlowCheckpoint("Completed Heading Extraction For File")
        metrics.getMetric(f"{index}: Heading Extraction")

        print(f"Starting Document Annotation For File :- {fileNamePartitioned}")        
        flowLogger.logFlowCheckpoint("Starting Document Annotation For File")
        documentAnnotationObj = DocumentAnnotation(fileNamePartitioned,'c20835db4b1b4e108828a8537ff41506','https://spor-sit.azure-api.net/pms/api/v2/',df,coll)
        try:
            pms_oms_annotation_data = documentAnnotationObj.processRegulatedAuthorizationForDoc()
            print(pms_oms_annotation_data)
        except:
            pms_oms_annotation_data = None
            print("Error Found")
            
        print(f"Completed Document Annotation")        
        flowLogger.logFlowCheckpoint("Completed Document Annotation")
        metrics.getMetric(f"{index}: Document Annotation")
        
        print(f"Starting Extracting Content Between Heading For File :- {fileNamePartitioned}")        
        flowLogger.logFlowCheckpoint("Starting Extracting Content Between Heading")
        
        extractContentlogger =  MatchLogger(f'ExtractContentBetween_{index}_{getRandomString(1)}', fileNamePartitioned, domain, procedureType, languageCode, index, fileNameLog)
        extractorObj = DataBetweenHeadingsExtractor(extractContentlogger, basePath, coll)
        dfExtractedHierRR = extractorObj.extractContentBetweenHeadings(fileNamePartitioned)
        
        print(f"Completed Extracting Content Between Heading")        
        flowLogger.logFlowCheckpoint("Completed Extracting Content Between Heading")
        metrics.getMetric(f"{index}: Content Extraction")
        
        xmlLogger =  MatchLogger(f'XmlGeneration_{index}_{getRandomString(1)}', fileNamePartitioned, domain, procedureType, languageCode, index, fileNameLog)
        fhirXmlGeneratorObj = FhirXmlGenerator(xmlLogger, controlBasePath, basePath, pms_oms_annotation_data, stylesFilePath, medName)
        fileNameXml = fileNamePartitioned.replace('.json','.xml')
        generatedXml = fhirXmlGeneratorObj.generateXml(dfExtractedHierRR, fileNameXml)
        
        metrics.getMetric(f"{index}: Generate XML")
        
        fhirServiceLogger =  MatchLogger(f'XML Submission Logger_{index}_{getRandomString(1)}', fileNamePartitioned, domain, procedureType, languageCode, index, fileNameLog)

        fhirServiceObj = FhirService(fhirServiceLogger, basePath, generatedXml)
        fhirServiceObj.submitFhirXml()
        
        metrics.getMetric(f"{index}: Submit FHIR Msg")
        
        print(f"Created XML File For :- {fileNamePartitioned}")      
        
        #return df,coll,dfExtractedHierRR
    
    
    flowLogger.logFlowCheckpoint("Completed Processing Partitioned Jsons")
    metrics.getMetric(f"{index}: Completed")
    metrics.end()

# %%
from wordToHtmlConvertor.wordToHtmlConvertor import WordToHtmlConvertor

wordToHtmlConvertorObj = WordToHtmlConvertor()
wordToHtmlConvertorObj.convertWordToHTML()
# Out:
# 2021-05-19 00:50:50,658 : WordToHtmlLogger_M : Input file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\ABASAGLAR~H~CAP~en.docx | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# 2021-05-19 00:50:50,659 : WordToHtmlLogger_M : Output file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\ABASAGLAR\en\2021-05-18T19-20-50Z\ABASAGLAR_clean | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# Word Files in folder:  ['ABASAGLAR~H~CAP~en.docx', 'Abilify Maintena~H~CAP~en.doc', 'ABILIFY~H~CAP~en.doc', 'Adakveo~H~CAP~en.docx', 'Adcetris~H~CAP~en.doc', '~$ilify Maintena~H~CAP~en.doc']
# Input file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\ABASAGLAR~H~CAP~en.docx
# Output file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\ABASAGLAR\en\2021-05-18T19-20-50Z\ABASAGLAR_clean
# 2021-05-19 00:51:09,654 : WordToHtmlLogger_M : Opened file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\ABASAGLAR~H~CAP~en.docx | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# Opened file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\ABASAGLAR~H~CAP~en.docx
# 2021-05-19 00:51:11,212 : WordToHtmlLogger_M : Starting document cleaning process | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# Checking table 20
# The selection starts on page 105 of 106 (69.44999694824219/70.75)
# The selection ends on page 105 of 106 (384.8500061035156/70.75)
# The selection contains
# * overlay images
#
# Checking table 19
# The selection starts on page 103 of 106 (579.2000122070312/70.75)
# The selection ends on page 105 of 106 (56.70000076293945/70.75)
# The selection contains
# * overlay images
#
# Checking table 18
# The selection starts on page 102 of 105 (564.5499877929688/214.75)
# The selection ends on page 103 of 105 (421.79998779296875/70.75)
# The selection contains
# * overlay images
# * overlay shapes
#
# Checking table 17
# The selection starts on page 102 of 105 (56.70000076293945/70.75)
# The selection ends on page 102 of 105 (475.95001220703125/70.75)
# The selection contains
# * overlay images
#
# Checking table 16
# The selection starts on page 100 of 105 (577.9000244140625/70.75)
# The selection ends on page 101 of 105 (484.25/70.75)
# The selection contains
# * overlay images
#
# Checking table 15
# The selection starts on page 100 of 105 (196.89999389648438/70.75)
# The selection ends on page 100 of 105 (331.95001220703125/70.75)
# The selection contains
# * overlay images
#
# Checking table 14
# The selection starts on page 100 of 105 (56.70000076293945/70.75)
# The selection ends on page 100 of 105 (196.89999389648438/70.75)
# The selection contains
# * inline images
#
# Checking table 13
# The selection starts on page 94 of 105 (612.9500122070312/70.75)
# The selection ends on page 95 of 105 (663.9500122070312/70.75)
# The selection contains
#
# Checking table 12
# The selection starts on page 86 of 105 (69.44999694824219/70.75)
# The selection ends on page 86 of 105 (416.70001220703125/70.75)
# The selection contains
# * overlay images
#
# Checking table 11
# The selection starts on page 84 of 105 (631.4500122070312/70.75)
# The selection ends on page 85 of 105 (744.8499755859375/70.75)
# The selection contains
# * overlay images
# * overlay shapes
#
# Checking table 10
# The selection starts on page 83 of 105 (767.7999877929688/70.75)
# The selection ends on page 84 of 105 (475.95001220703125/70.75)
# The selection contains
# * overlay images
# * overlay shapes
#
# Checking table 9
# The selection starts on page 83 of 105 (237.64999389648438/70.75)
# The selection ends on page 83 of 105 (660.0999755859375/70.75)
# The selection contains
# * overlay images
#
# Checking table 8
# The selection starts on page 82 of 105 (406.5/70.75)
# The selection ends on page 83 of 105 (153.5500030517578/70.75)
# The selection contains
# * overlay images
# * overlay shapes
#
# Checking table 7
# The selection starts on page 81 of 106 (667.75/70.75)
# The selection ends on page 82 of 106 (138.25/70.75)
# The selection contains
# * inline images
#
# Checking table 6
# The selection starts on page 81 of 106 (545.4000244140625/70.75)
# The selection ends on page 81 of 106 (667.75/70.75)
# The selection contains
# * inline images
#
# Checking table 5
# The selection starts on page 81 of 106 (112.80000305175781/70.75)
# The selection ends on page 81 of 106 (194.9499969482422/70.75)
# The selection contains
# * inline images
#
# Checking table 4
# The selection starts on page 76 of 106 (525.0499877929688/70.75)
# The selection ends on page 77 of 106 (575.3499755859375/70.75)
# The selection contains
#
# Checking table 3
# The selection starts on page 64 of 106 (639.0999755859375/70.75)
# The selection ends on page 66 of 106 (107.05000305175781/70.75)
# The selection contains
#
# Checking table 2
# The selection starts on page 22 of 106 (158.0/70.75)
# The selection ends on page 22 of 106 (503.3500061035156/70.75)
# The selection contains
#
# Checking table 1
# The selection starts on page 7 of 106 (512.2999877929688/70.75)
# The selection ends on page 8 of 106 (358.75/70.75)
# The selection contains
# 2021-05-19 00:51:51,072 : WordToHtmlLogger_M : Completed document cleaning process | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# 2021-05-19 00:51:51,078 : WordToHtmlLogger_M : Preparing zip file | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# 2021-05-19 00:51:52,742 : WordToHtmlLogger_M : Zip file created: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\ABASAGLAR~H~CAP~en~2021-05-18T19-20-50Z.zip | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# 2021-05-19 00:51:52,746 : WordToHtmlLogger_M : Uploading to Azure Storage as blob:
# 	F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\ABASAGLAR~H~CAP~en~2021-05-18T19-20-50Z.zip | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# Uploading File to  Azure Storage:
# 	F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\ABASAGLAR~H~CAP~en~2021-05-18T19-20-50Z.zip
# 2021-05-19 00:52:05,189 : WordToHtmlLogger_M : Uploaded F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\ABASAGLAR~H~CAP~en~2021-05-18T19-20-50Z.zipsuccessfully | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# 2021-05-19 00:52:05,190 : WordToHtmlLogger_M : Deleting input word file: ABASAGLAR~H~CAP~en.docx | H | CAP |  en | .docx | ABASAGLAR~H~CAP~en.docx
# 2021-05-19 00:52:05,217 : WordToHtmlLogger_2 : Input file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\Abilify Maintena~H~CAP~en.doc | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# 2021-05-19 00:52:05,218 : WordToHtmlLogger_2 : Output file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Abilify Maintena\en\2021-05-18T19-22-05Z\Abilify Maintena_clean | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# Input file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\Abilify Maintena~H~CAP~en.doc
# Output file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Abilify Maintena\en\2021-05-18T19-22-05Z\Abilify Maintena_clean
# 2021-05-19 00:54:18,892 : WordToHtmlLogger_2 : Opened file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\Abilify Maintena~H~CAP~en.doc | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# Opened file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\data\Ingest\Abilify Maintena~H~CAP~en.doc
# 2021-05-19 00:54:20,499 : WordToHtmlLogger_2 : Starting document cleaning process | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# Checking table 23
# The selection starts on page 95 of 95 (619.3499755859375/70.75)
# The selection ends on page 95 of 95 (737.2000122070312/70.75)
# The selection contains
# * inline images
#
# Checking table 22
# The selection starts on page 95 of 95 (303.29998779296875/70.75)
# The selection ends on page 95 of 95 (480.3999938964844/70.75)
# The selection contains
# * inline images
#
# Checking table 21
# The selection starts on page 95 of 95 (107.05000305175781/70.75)
# The selection ends on page 95 of 95 (227.4499969482422/70.75)
# The selection contains
# * inline images
#
# Checking table 20
# The selection starts on page 94 of 95 (653.0999755859375/70.75)
# The selection ends on page 95 of 95 (56.70000076293945/70.75)
# The selection contains
# * inline images
#
# Checking table 19
# The selection starts on page 94 of 95 (494.45001220703125/70.75)
# The selection ends on page 94 of 95 (627.5999755859375/70.75)
# The selection contains
# * inline images
#
# Checking table 18
# The selection starts on page 94 of 95 (353.0/70.75)
# The selection ends on page 94 of 95 (456.20001220703125/70.75)
# The selection contains
#
# Checking table 17
# The selection starts on page 94 of 95 (145.25/70.75)
# The selection ends on page 94 of 95 (315.3999938964844/70.75)
# The selection contains
# * inline images
#
# Checking table 16
# The selection starts on page 93 of 95 (581.75/70.75)
# The selection ends on page 93 of 95 (726.3499755859375/70.75)
# The selection contains
# * inline images
#
# Checking table 15
# The selection starts on page 93 of 95 (398.25/70.75)
# The selection ends on page 93 of 95 (543.5/70.75)
# The selection contains
# * inline images
#
# Checking table 14
# The selection starts on page 91 of 95 (436.45001220703125/70.75)
# The selection ends on page 92 of 95 (499.54998779296875/70.75)
# The selection contains
#
# Checking table 13
# The selection starts on page 82 of 95 (484.8999938964844/70.75)
# The selection ends on page 82 of 95 (582.3499755859375/70.75)
# The selection contains
# * inline images
#
# Checking table 12
# The selection starts on page 82 of 95 (184.14999389648438/70.75)
# The selection ends on page 82 of 95 (345.3500061035156/70.75)
# The selection contains
# * inline images
#
# Checking table 11
# The selection starts on page 81 of 95 (697.7000122070312/70.75)
# The selection ends on page 82 of 95 (108.30000305175781/70.75)
# The selection contains
#
# Checking table 10
# The selection starts on page 81 of 95 (286.75/70.75)
# The selection ends on page 81 of 95 (378.5/70.75)
# The selection contains
#
# Checking table 9
# The selection starts on page 81 of 95 (194.35000610351562/70.75)
# The selection ends on page 81 of 95 (286.75/70.75)
# The selection contains
#
# Checking table 8
# The selection starts on page 80 of 95 (235.10000610351562/70.75)
# The selection ends on page 80 of 95 (333.25/70.75)
# The selection contains
# * inline images
#
# Checking table 7
# The selection starts on page 79 of 95 (525.0499877929688/70.75)
# The selection ends on page 79 of 95 (658.2000122070312/70.75)
# The selection contains
# * inline images
#
# Checking table 6
# The selection starts on page 77 of 95 (410.95001220703125/70.75)
# The selection ends on page 78 of 95 (474.04998779296875/70.75)
# The selection contains
#
# Checking table 5
# The selection starts on page 16 of 95 (461.29998779296875/70.75)
# The selection ends on page 16 of 95 (604.0499877929688/70.75)
# The selection contains
#
# Checking table 4
# The selection starts on page 15 of 95 (519.2999877929688/70.75)
# The selection ends on page 15 of 95 (659.4500122070312/70.75)
# The selection contains
#
# Checking table 3
# The selection starts on page 9 of 95 (512.2999877929688/70.75)
# The selection ends on page 12 of 95 (186.6999969482422/70.75)
# The selection contains
#
# Checking table 2
# The selection starts on page 4 of 95 (499.54998779296875/105.75)
# The selection ends on page 4 of 95 (642.9000244140625/70.75)
# The selection contains
#
# Checking table 1
# The selection starts on page 3 of 95 (296.8999938964844/70.75)
# The selection ends on page 3 of 95 (579.7999877929688/70.75)
# The selection contains
# 2021-05-19 00:54:46,529 : WordToHtmlLogger_2 : Completed document cleaning process | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# 2021-05-19 00:54:46,532 : WordToHtmlLogger_2 : Preparing zip file | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# 2021-05-19 00:54:47,821 : WordToHtmlLogger_2 : Zip file created: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\Abilify Maintena~H~CAP~en~2021-05-18T19-22-05Z.zip | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# 2021-05-19 00:54:47,825 : WordToHtmlLogger_2 : Uploading to Azure Storage as blob:
# 	F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\Abilify Maintena~H~CAP~en~2021-05-18T19-22-05Z.zip | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# Uploading File to  Azure Storage:
# 	F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\Abilify Maintena~H~CAP~en~2021-05-18T19-22-05Z.zip
# 2021-05-19 00:54:59,563 : WordToHtmlLogger_2 : Uploaded F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob\Abilify Maintena~H~CAP~en~2021-05-18T19-22-05Z.zipsuccessfully | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# 2021-05-19 00:54:59,564 : WordToHtmlLogger_2 : Deleting input word file: Abilify Maintena~H~CAP~en.doc | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# 2021-05-19 00:54:59,573 : WordToHtmlLogger_2 : Killing Word processes as exception was raised | H | CAP |  en | .doc | Abilify Maintena~H~CAP~en.doc
# Exception raised
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# Killing WINWORD.EXE
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# F:\Projects\EMA\Repository\EMA EPI PoC\function_code\code\wordToHtmlConvertor\wordToHtmlConvertor.py in cleanWordAndGenerateHtml(self, in_folder_path, filename)
#     228
# --> 229                 os.remove(in_file)
#     230
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'F:\\Projects\\EMA\\Repository\\EMA EPI PoC\\function_code\\data\\Ingest\\Abilify Maintena~H~CAP~en.doc'
#
# During handling of the above exception, another exception occurred:
#
# ProcessLookupError                        Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psutil\_pswindows.py in wrapper(self, *args, **kwargs)
#     715         try:
# --> 716             return fun(self, *args, **kwargs)
#     717         except OSError as err:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psutil\_pswindows.py in exe(self)
#     773         if not IS_WIN_XP:
# --> 774             exe = cext.proc_exe(self.pid)
#     775         else:
#
# ProcessLookupError: [Errno 3] No such process
#
# During handling of the above exception, another exception occurred:
#
# NoSuchProcess                             Traceback (most recent call last)
# <ipython-input-3-c9cd854d298e> in <module>
#       1 wordToHtmlConvertorObj = WordToHtmlConvertor()
# ----> 2 wordToHtmlConvertorObj.convertWordToHTML()
#
# F:\Projects\EMA\Repository\EMA EPI PoC\function_code\code\wordToHtmlConvertor\wordToHtmlConvertor.py in convertWordToHTML(self)
#     254         for filename in doc_file_list:
#     255              if(not filename.startswith('~')):
# --> 256                 self.cleanWordAndGenerateHtml(in_folder_path, filename)
#
# <C:\Users\vipsharm\AppData\Local\Continuum\anaconda3\lib\site-packages\decorator.py:decorator-gen-130> in cleanWordAndGenerateHtml(self, in_folder_path, filename)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\retry\api.py in retry_decorator(f, *fargs, **fkwargs)
#      72         kwargs = fkwargs if fkwargs else dict()
#      73         return __retry_internal(partial(f, *args, **kwargs), exceptions, tries, delay, max_delay, backoff, jitter,
# ---> 74                                 logger)
#      75
#      76     return retry_decorator
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\retry\api.py in __retry_internal(f, exceptions, tries, delay, max_delay, backoff, jitter, logger)
#      31     while _tries:
#      32         try:
# ---> 33             return f()
#      34         except exceptions as e:
#      35             _tries -= 1
#
# F:\Projects\EMA\Repository\EMA EPI PoC\function_code\code\wordToHtmlConvertor\wordToHtmlConvertor.py in cleanWordAndGenerateHtml(self, in_folder_path, filename)
#     240             for proc in psutil.process_iter():
#     241                 # Check whether the process name matches
# --> 242                 if proc.name() == 'WINWORD.EXE':
#     243                     print(f'Killing {proc.name()}')
#     244                     proc.kill()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psutil\__init__.py in name(self)
#     728         if WINDOWS and self._name is not None:
#     729             return self._name
# --> 730         name = self._proc.name()
#     731         if POSIX and len(name) >= 15:
#     732             # On UNIX the name gets truncated to the first 15 characters.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psutil\_pswindows.py in wrapper(self, *args, **kwargs)
#     714     def wrapper(self, *args, **kwargs):
#     715         try:
# --> 716             return fun(self, *args, **kwargs)
#     717         except OSError as err:
#     718             raise convert_oserror(err, pid=self.pid, name=self._name)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psutil\_pswindows.py in name(self)
#     763                 # Note: this will fail with AD for most PIDs owned
#     764                 # by another user but it's faster.
# --> 765                 return py2_strencode(os.path.basename(self.exe()))
#     766             except AccessDenied:
#     767                 return py2_strencode(cext.proc_name(self.pid))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\psutil\_pswindows.py in wrapper(self, *args, **kwargs)
#     716             return fun(self, *args, **kwargs)
#     717         except OSError as err:
# --> 718             raise convert_oserror(err, pid=self.pid, name=self._name)
#     719     return wrapper
#     720
#
# NoSuchProcess: psutil.NoSuchProcess process no longer exists (pid=34304)

# %%
# inputZipFolderPath = "F:\Projects\EMA\Repository\EMA EPI PoC\\function_code\\inputblob"
inputZipFolderPath = os.path.abspath(os.path.join('..'))
inputZipFolderPath = os.path.join(inputZipFolderPath, 'inputblob')
inputZipFileName = "Zynteglo~H~CAP~en~2021-05-19T07-52-54Z.zip"

# %%
fileNameQrd = 'qrd_canonical_model.csv'
fileNameMatchRuleBook = 'ruleDict.json'
fileNameDocumentTypeNames = 'documentTypeNames.json'
fsMountName = '/mounted'

info = inputZipFileName.split("~")

try:
    medName = info[0]
    domain = info[1]
    procedureType = info[2]
    languageCode = info[3]
    timestamp = info[4]
    timestamp = timestamp.replace(".zip","")

except Exception:
    raise f"Missing required info in the zip file name {inputZipFileName}"

if "\\" in os.getcwd():
    localEnv = True
    inputZipFolderPath = os.path.join(os.path.abspath(os.path.join('..')),inputZipFolderPath)
    outputFolderPath = os.path.join(os.path.abspath(os.path.join('..')), 'work', f"{domain}", f"{procedureType}", f"{medName}", f"{languageCode}", f"{timestamp}")
    controlFolderPath = os.path.join(os.path.abspath(os.path.join('..')),'control')
else:
    localEnv = False
    inputZipFolderPath = os.path.join(f'{fsMountName}',inputZipFolderPath)
    outputFolderPath = os.path.join(f'{fsMountName}', 'work', f"{domain}", f"{procedureType}", f"{medName}", f"{languageCode}", f"{timestamp}")
    controlFolderPath = os.path.join(f'{fsMountName}','control')


print(inputZipFileName, inputZipFolderPath, outputFolderPath, controlFolderPath)

mode = 0o666

if localEnv is True:
    inputZipFolderPath = inputZipFolderPath.replace("/","\\")
    outputFolderPath = outputFolderPath.replace("/","\\")
    controlFolderPath = controlFolderPath.replace("/","\\")

try:
    os.makedirs(inputZipFolderPath, mode)
    os.makedirs(outputFolderPath, mode)
    os.makedirs(controlFolderPath, mode)

except Exception:
    print("Already Present")
    
with zipfile.ZipFile(f'{inputZipFolderPath}/{inputZipFileName}',"r") as zip_ref:
        zip_ref.extractall(outputFolderPath)
    

_,_,fileNames = next(os.walk(outputFolderPath))
htmlFileName = [fileName for fileName in fileNames if ".htm" in fileName][0]

print(htmlFileName)
# Out:
# Zynteglo~H~CAP~en~2021-05-19T07-52-54Z.zip F:\Projects\EMA\Repository\EMA EPI PoC\function_code\inputblob F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z F:\Projects\EMA\Repository\EMA EPI PoC\function_code\control
# Already Present
# Zynteglo_clean.htm

# %%
parseDocument(controlFolderPath, outputFolderPath, htmlFileName, fileNameQrd, fileNameMatchRuleBook, fileNameDocumentTypeNames, medName)
# Out:
# 2021-05-20 00:22:58,330 : Flow Logger HTML_2 : Starting HTML Conversion To Json | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:22:58,336 : Style Dictionary_v : Reading style dictionary in file: rule_dictionary_en.json | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:22:58,336 : Style Dictionary_v : Reading style dictionary in file: rule_dictionary_en.json | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:22:58,367 : Style Dictionary_v : Qrd Section Keys Retrieved For Style Dictionary: ANNEX I, ANNEX II, ANNEX III, B. PACKAGE LEAFLET | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:22:58,367 : Style Dictionary_v : Qrd Section Keys Retrieved For Style Dictionary: ANNEX I, ANNEX II, ANNEX III, B. PACKAGE LEAFLET | H | CAP |  en | HTML | Zynteglo_clean.htm
# ['F:', 'Projects', 'EMA', 'Repository', 'EMA EPI PoC', 'function_code', 'work', 'H', 'CAP', 'Zynteglo', 'en', '2021-05-19T07-52-54Z'] Zynteglo_clean.htm
# 2021-05-19T07-52-54Z en Zynteglo CAP H
# ------------- F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.txt -----------------
# F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\Zynteglo_clean.htm F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.json
# 2021-05-20 00:22:58,855 : Parser_b : Style Information Stored In File: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.txt | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:22:58,855 : Parser_b : Style Information Stored In File: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.txt | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,108 : Parser_b : Writing to file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.json | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,108 : Parser_b : Writing to file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.json | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,315 : Flow Logger HTML_2 : Completed HTML Conversion To Json | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,317 : Flow Logger HTML_2 : HTML Conversion To Json,0.0665 Min,5.550037 MB,10.13895 MB,66.4%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,326 : Flow Logger HTML_2 : Starting Json Split | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,331 : Style Dictionary_Z : Reading style dictionary in file: rule_dictionary_en.json | H | CAP |  en | Json | Zynteglo_clean.json
# 2021-05-20 00:23:02,366 : Style Dictionary_Z : Qrd Section Keys Retrieved For Style Dictionary: ANNEX I, ANNEX II, ANNEX III, B. PACKAGE LEAFLET | H | CAP |  en | Json | Zynteglo_clean.json
# 2021-05-20 00:23:02,373 : Partition_h : Partitioning Json: Zynteglo_clean.json | H | CAP |  en | Json | Zynteglo_clean.json
# 2021-05-20 00:23:02,507 : Partition_h : Writing partition to file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\partitionedJSONs\Zynteglo_clean_SmPC.json | H | CAP |  en | Json | Zynteglo_clean.json
# stylePath:- F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.txt
# Metrics : HTML Conversion To Json,0.0665 Min,5.550037 MB,10.13895 MB,66.4%
#
# PathJson F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\outputJSON\Zynteglo_clean.json
# 2021-05-20 00:23:02,575 : Partition_h : Writing partition to file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\partitionedJSONs\Zynteglo_clean_ANNEX II.json | H | CAP |  en | Json | Zynteglo_clean.json
# 2021-05-20 00:23:02,641 : Partition_h : Writing partition to file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\partitionedJSONs\Zynteglo_clean_ANNEX III.json | H | CAP |  en | Json | Zynteglo_clean.json
# 2021-05-20 00:23:02,650 : Partition_h : Writing partition to file: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\partitionedJSONs\Zynteglo_clean_ PACKAGE LEAFLET.json | H | CAP |  en | Json | Zynteglo_clean.json
# 2021-05-20 00:23:02,663 : Flow Logger HTML_2 : ['Zynteglo_clean_SmPC.json', 'Zynteglo_clean_ANNEX II.json', 'Zynteglo_clean_ANNEX III.json', 'Zynteglo_clean_ PACKAGE LEAFLET.json'] | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,664 : Flow Logger HTML_2 : Completed Json Split | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,666 : Flow Logger HTML_2 : Split Json,0.0057 Min,0.452009 MB,8.733447 MB,66.4%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,667 : Flow Logger HTML_2 : Started Processing Partitioned Jsons | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,669 : Flow Logger HTML_2 :
#
#
#
# ||||||||||||||||||||||||||||||||0 ||||| Zynteglo_clean_SmPC.json||||||||||||||||||||||||||||||||
#
#
#
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:23:02,676 : Heading Extraction Zynteglo_clean_SmPC.json_L : Starting Heading Extraction | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json
# Metrics : Split Json,0.0057 Min,0.452009 MB,8.733447 MB,66.4%
#
# Starting Heading Extraction For File :- Zynteglo_clean_SmPC.json
# File being processed: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\partitionedJSONs\Zynteglo_clean_SmPC.json
# --------------------------------------------
# SmPC
# 2021-05-20 00:23:03,172 : Heading Extraction Zynteglo_clean_SmPC.json_L : Started Extracting Heading | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json
# 2021-05-20 00:23:03,455 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'SUMMARY OF PRODUCT CHARACTERISTICS' | Qrd txt :- 'SUMMARY OF PRODUCT CHARACTERISTICS' | Matched :- 'True'
# 2021-05-20 00:23:03,461 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed As This The First Heading | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20001' | prevHeadingCurrId :- '' | prevHeadingFoundId :- ''
# 2021-05-20 00:23:03,750 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed : checkLowerCase|2.88|(99, 100, 99)|0.919| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'medicinal product subject additional monitoring. allow quick identification new safety information. healthcare professionals asked report suspected adverse reactions. see section 4.8 report adverse reactions.' | Qrd txt :- 'qthis medicinal product subject additional monitoring. allow quick identification new safety information. healthcare professionals asked report suspected adverse reactions. see section 4.8 report adverse reactions.' | Matched :- 'True'
#  See section 4.8 for how to report adverse reactions.' | Qrd txt :- 'qThis medicinal product is subject to additional monitoring. This will allow quick identification of new safety information. Healthcare professionals are asked to report any suspected adverse reactions. See section 4.8 for how to report adverse reactions.' | Matched :- 'True'
# 2021-05-20 00:23:03,777 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20002' | prevHeadingCurrId :- '20001' | prevHeadingFoundId :- '20001'
# OriginalCheck
#
# ----------------------------------
# RemovedByStyle
# ----------------------------------
# 2021-05-20 00:23:03,789 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed By Style | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20002' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20001'
# 2021-05-20 00:23:03,912 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '1. NAME OF THE MEDICINAL PRODUCT' | Qrd txt :- '1. NAME OF THE MEDICINAL PRODUCT' | Matched :- 'True'
# 2021-05-20 00:23:03,929 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20003' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20001'
# 2021-05-20 00:23:03,937 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20003' | prevHeadingCurrId :- '20001' | prevHeadingFoundId :- '20001'
#  dispersion for infusion. ' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'0.62| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Zynteglo 1.2‑20 × 106 cells/mL
# 2021-05-20 00:23:04,426 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '2. QUALITATIVE AND QUANTITATIVE COMPOSITION' | Qrd txt :- '2. QUALITATIVE AND QUANTITATIVE COMPOSITION' | Matched :- 'True'
# 2021-05-20 00:23:04,438 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20004' | prevHeadingCurrId :- '20003' | prevHeadingFoundId :- '20003'
# 2021-05-20 00:23:04,475 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '2.1 General description' | Qrd txt :- '2.1 General description' | Matched :- 'True'
# 2021-05-20 00:23:04,486 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20005' | prevHeadingCurrId :- '20004' | prevHeadingFoundId :- '20004'
# 2021-05-20 00:23:04,706 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed : checkLowerCase|2.27|(99, 98, 99)|0.997| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '2.2 qualitative and quantitative composition' | Qrd txt :- '2. qualitative and quantitative composition' | Matched :- 'True'
#  quantitative composition' | Qrd txt :- '2. QUALITATIVE AND QUANTITATIVE COMPOSITION' | Matched :- 'True'eckLowerCase|2.27|(99, 98, 99)|0.997| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '2.2     Qualitative and
# 2021-05-20 00:23:04,717 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed SmPc Special Case | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20004' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20005'
# 2021-05-20 00:23:04,729 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '2.2 Qualitative and quantitative composition' | Qrd txt :- '2.2 Qualitative and quantitative composition' | Matched :- 'True'
# 2021-05-20 00:23:04,743 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20006' | prevHeadingCurrId :- '20005' | prevHeadingFoundId :- '20005'
# OriginalCheck
# 2021-05-20 00:23:05,035 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed : <=4|11.11|(95, 89, 95)|0.989| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Excipient with known effect' | Qrd txt :- 'Excipient(s) with known effect' | Matched :- 'True'
# 2021-05-20 00:23:05,050 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20007' | prevHeadingCurrId :- '20006' | prevHeadingFoundId :- '20006'
# 2021-05-20 00:23:05,752 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '3. PHARMACEUTICAL FORM' | Qrd txt :- '3. PHARMACEUTICAL FORM' | Matched :- 'True'
# 2021-05-20 00:23:05,762 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20008' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20006'
# 2021-05-20 00:23:05,770 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20008' | prevHeadingCurrId :- '20006' | prevHeadingFoundId :- '20006'
# 2021-05-20 00:23:06,245 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4. CLINICAL PARTICULARS' | Qrd txt :- '4. CLINICAL PARTICULARS' | Matched :- 'True'
# 2021-05-20 00:23:06,255 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20009' | prevHeadingCurrId :- '20008' | prevHeadingFoundId :- '20008'
#  indication' | Qrd txt :- '4.1 Therapeutic indications' | Matched :- 'True'atch Passed : <=4|3.85|(98, 100, 98)|0.996| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.1     Therapeutic
# 2021-05-20 00:23:06,340 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20010' | prevHeadingCurrId :- '20009' | prevHeadingFoundId :- '20009'
# 2021-05-20 00:23:06,460 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.2 Posology and method of administration' | Qrd txt :- '4.2 Posology and method of administration' | Matched :- 'True'
# 2021-05-20 00:23:06,475 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20011' | prevHeadingCurrId :- '20010' | prevHeadingFoundId :- '20010'
#  in HSC transplantation and in the treatment of patients with TDT. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'e
# 2021-05-20 00:23:06,826 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Posology' | Qrd txt :- 'Posology' | Matched :- 'True'
# 2021-05-20 00:23:06,848 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20012' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
#  4.4) and should only be administered once.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False' txt :- 'Zynteglo is intended for autologous use (see section
# 2021-05-20 00:23:07,847 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|134.62|(38, 42, 86)|0.658| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Mobilisation and apheresis' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
#  conditioning is initiated (see section 4.4). ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False't :- 'The treating physician should confirm that HSC
#  details on Zynteglo administration and handling.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'- 'See Method of Administration below and section 6.6 for
#  details on Zynteglo administration and handling.' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'| 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'See Method of Administration below and section 6.6 for
#  3 months after Zynteglo infusion should be irradiated. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'blood products required within the first
# 2021-05-20 00:23:11,193 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|173.68|(45, 79, 86)|0.644| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Special populations' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
# 2021-05-20 00:23:12,694 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:12,716 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20013' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,733 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20013' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,766 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:12,785 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20019' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,802 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20019' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,811 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:12,830 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20021' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,849 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20021' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,882 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:12,899 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20028' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,914 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20028' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,934 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:12,953 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20031' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,970 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20031' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:12,997 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:13,013 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20037' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:13,030 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20037' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:13,116 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|171.43|(29, 48, 47)|0.629| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
#  <12 years of age have not yet been established. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False':- 'The safety and efficacy of Zynteglo in children
#  <12 years of age have not yet been established. ' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'| 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'The safety and efficacy of Zynteglo in children
#  (HIV) or human T‑lymphotropic virus (HTLV)' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False' txt :- 'Patients seropositive for human immunodeficiency virus
# 2021-05-20 00:23:14,135 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Method of administration' | Qrd txt :- 'Method of administration' | Matched :- 'True'
# 2021-05-20 00:23:14,153 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20014' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:14,172 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20014' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
#  for full details on the administration process).' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'- 'Zynteglo is for intravenous use only (see section 6.6
#  for full details on the administration process).' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'| 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Zynteglo is for intravenous use only (see section 6.6
#  before Zynteglo infusion. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'SmPC.json | Doc txt :- 'After completion of the 4‑day course of
#  transplantation should be followed after Zynteglo infusion.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False' procedures for patient management after HSC
# 2021-05-20 00:23:15,287 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.3 Contraindications' | Qrd txt :- '4.3 Contraindications' | Matched :- 'True'
# 2021-05-20 00:23:15,302 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20016' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20011'
# 2021-05-20 00:23:15,312 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20016' | prevHeadingCurrId :- '20011' | prevHeadingFoundId :- '20011'
#  the excipients listed in section 6.1.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'| Doc txt :- 'Hypersensitivity to the active substance or to any of
#  myeloablative conditioning agent must be considered.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'ontraindications to the mobilisation agents and the
# 2021-05-20 00:23:16,734 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.4 Special warnings and precautions for use' | Qrd txt :- '4.4 Special warnings and precautions for use' | Matched :- 'True'
# 2021-05-20 00:23:16,747 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20017' | prevHeadingCurrId :- '20016' | prevHeadingFoundId :- '20016'
# 2021-05-20 00:23:16,831 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Traceability' | Qrd txt :- 'Traceability' | Matched :- 'True'
# 2021-05-20 00:23:16,855 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20018' | prevHeadingCurrId :- '20017' | prevHeadingFoundId :- '20017'
#  and the myeloablative conditioning agent must be considered.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'and precautions of the mobilisation agents
#  and the myeloablative conditioning agent must be considered.' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'lo_clean_SmPC.json | Doc txt :- 'Warnings and precautions of the mobilisation agents
# 2021-05-20 00:23:18,495 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|112.9|(31, 35, 29)|0.609| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Risk of insertional oncogenesis' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
#  Zynteglo manufacturing (see section 4.2). ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'txt :- 'All patients should be tested for HIV-1/2 prior to
#  engraftment' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'| Zynteglo_clean_SmPC.json | Doc txt :- 'Engraftment failure as measured by neutrophil
#  intake of 2 g sodium for an adult. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'n | Doc txt :- 'This medicinal product contains 391‑1564 mg
# 2021-05-20 00:23:21,360 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.5 Interaction with other medicinal products and other forms of interaction' | Qrd txt :- '4.5 Interaction with other medicinal products and other forms of interaction' | Matched :- 'True'
# 2021-05-20 00:23:21,375 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20020' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20017'
# 2021-05-20 00:23:21,386 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20020' | prevHeadingCurrId :- '20017' | prevHeadingFoundId :- '20017'
#  until at least 7 days after Zynteglo infusion (see section 4.4).' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'ld not take anti‑retroviral
#  family of enzymes or drug transporters.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'Doc txt :- 'No formal drug interaction studies have been
#  erythropoiesis-stimulating agents in patients treated with Zynteglo.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'cal experience with the use of
#  during or following Zynteglo treatment has not been studied. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False' of immunisation with live viral vaccines
# 2021-05-20 00:23:22,724 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.6 Fertility, pregnancy and lactation' | Qrd txt :- '4.6 Fertility, pregnancy and lactation' | Matched :- 'True'
# 2021-05-20 00:23:22,739 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20022' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20020'
# 2021-05-20 00:23:22,751 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20022' | prevHeadingCurrId :- '20020' | prevHeadingFoundId :- '20020'
#  and females' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False' Zynteglo_clean_SmPC.json | Doc txt :- 'Women of childbearing potential/Contraception in males
#  and females' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'|(33, 35, 35)|0.612| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Women of childbearing potential/Contraception in males
# 2021-05-20 00:23:23,175 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Pregnancy' | Qrd txt :- 'Pregnancy' | Matched :- 'True'
# 2021-05-20 00:23:23,194 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20023' | prevHeadingCurrId :- '20022' | prevHeadingFoundId :- '20022'
#  procedures and before medicinal product administration.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'gative serum pregnancy test must be confirmed
# 2021-05-20 00:23:23,774 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase1|152.27|(19, 28, 27)|0.615| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'No clinical data on exposed pregnancies are available.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'
# 2021-05-20 00:23:23,788 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|88.64|(26, 29, 31)|0.666| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'No clinical data on exposed pregnancies are available.' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
# 2021-05-20 00:23:24,109 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Breast-feeding' | Qrd txt :- 'Breast-feeding' | Matched :- 'True'
# 2021-05-20 00:23:24,126 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20024' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20022'
# 2021-05-20 00:23:24,145 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20024' | prevHeadingCurrId :- '20022' | prevHeadingFoundId :- '20022'
#  children has not been studied.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'C.json | Doc txt :- 'It is unknown whether Zynteglo is excreted in human
#  breast-feeding.' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False', 26, 29)|0.607| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Zynteglo must not be administered to women who are
# 2021-05-20 00:23:24,805 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Fertility' | Qrd txt :- 'Fertility' | Matched :- 'True'
# 2021-05-20 00:23:24,822 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20025' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20022'
# 2021-05-20 00:23:24,838 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20025' | prevHeadingCurrId :- '20022' | prevHeadingFoundId :- '20022'
#  animal studies. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'eglo_clean_SmPC.json | Doc txt :- 'There are no data on the effects of Zynteglo on human
#  to cryopreserve semen or ova before treatment if possible.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'e available on the risk of infertility with
# 2021-05-20 00:23:25,717 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.7 Effects on ability to drive and use machines' | Qrd txt :- '4.7 Effects on ability to drive and use machines' | Matched :- 'True'
# 2021-05-20 00:23:25,734 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20026' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20022'
# 2021-05-20 00:23:25,745 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20026' | prevHeadingCurrId :- '20022' | prevHeadingFoundId :- '20022'
#  be considered.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'nteglo_clean_SmPC.json | Doc txt :- 'The effect of the mobilisation agents and the
# 2021-05-20 00:23:26,404 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.8 Undesirable effects' | Qrd txt :- '4.8 Undesirable effects' | Matched :- 'True'
# 2021-05-20 00:23:26,418 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20027' | prevHeadingCurrId :- '20026' | prevHeadingFoundId :- '20026'
# 2021-05-20 00:23:27,087 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|111.43|(27, 31, 44)|0.612| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Tabulated list of adverse reactions  ' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
#  1              Adverse reactions attributed to mobilisation/apheresis' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'
#  reactions attributed to myeloablative conditioning' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False' 'Table 2              Adverse
#  reactions attributed to myeloablative conditioning' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Table 2              Adverse
# 2021-05-20 00:23:28,615 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase1|153.66|(29, 42, 40)|0.642| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Description of selected adverse reactions' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'
# 2021-05-20 00:23:29,017 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|130.0|(31, 40, 36)|0.613| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Hepatic veno-occlusive disease' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
# 2021-05-20 00:23:29,396 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:29,406 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Wrong Heading Found | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20013' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,430 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:29,440 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Wrong Heading Found | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20019' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,448 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:29,458 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Previous Heading Found is not matching | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20021' | prevHeadingCurrId :- '20020' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,480 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:29,494 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20028' | prevHeadingCurrId :- '20027' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,505 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:29,520 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20031' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,532 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20031' | prevHeadingCurrId :- '20027' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,551 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:29,567 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20037' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,580 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20037' | prevHeadingCurrId :- '20027' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,646 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|171.43|(29, 48, 47)|0.629| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
# 2021-05-20 00:23:29,934 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Reporting of suspected adverse reactions' | Qrd txt :- 'Reporting of suspected adverse reactions' | Matched :- 'True'
# 2021-05-20 00:23:29,946 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20029' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:29,957 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20029' | prevHeadingCurrId :- '20027' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:30,062 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase1|157.5|(35, 42, 38)|0.626| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Reporting of suspected adverse reactions' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'
# 2021-05-20 00:23:30,203 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '4.9 Overdose' | Qrd txt :- '4.9 Overdose' | Matched :- 'True'
# 2021-05-20 00:23:30,216 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20030' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20027'
# 2021-05-20 00:23:30,224 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20030' | prevHeadingCurrId :- '20027' | prevHeadingFoundId :- '20027'
#  overdose of Zynteglo. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'clean_SmPC.json | Doc txt :- 'No data from clinical studies are available regarding
#  overdose of Zynteglo. ' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'9)|0.631| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'No data from clinical studies are available regarding
# 2021-05-20 00:23:30,569 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '5. PHARMACOLOGICAL PROPERTIES' | Qrd txt :- '5. PHARMACOLOGICAL PROPERTIES' | Matched :- 'True'
# 2021-05-20 00:23:30,583 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20032' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20030'
# 2021-05-20 00:23:30,591 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20032' | prevHeadingCurrId :- '20030' | prevHeadingFoundId :- '20030'
# 2021-05-20 00:23:30,731 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- '5.1 Pharmacodynamic properties' | Qrd txt :- '5.1 Pharmacodynamic properties' | Matched :- 'True'
# 2021-05-20 00:23:30,741 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20033' | prevHeadingCurrId :- '20032' | prevHeadingFoundId :- '20032'
# 2021-05-20 00:23:31,111 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Mechanism of action' | Qrd txt :- 'Mechanism of action' | Matched :- 'True'
# 2021-05-20 00:23:31,125 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20034' | prevHeadingCurrId :- '20033' | prevHeadingFoundId :- '20033'
# 2021-05-20 00:23:31,359 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Pharmacodynamic effects' | Qrd txt :- 'Pharmacodynamic effects' | Matched :- 'True'
# 2021-05-20 00:23:31,370 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Flow Is Broken | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20035' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20033'
# 2021-05-20 00:23:31,382 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Current H3 Heading Is Not Part Of Valid H3 Headings in Previous H2 | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20035' | prevHeadingCurrId :- '20033' | prevHeadingFoundId :- '20033'
# 2021-05-20 00:23:32,740 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Failed : SpecialCase2|134.62|(38, 42, 86)|0.658| | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Mobilisation and apheresis' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'
#  practice with ursodeoxycholic acid or defibrotide. ' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'In HGB‑207 and HGB‑212 prophylaxis for
#  as an intravenous infusion (N=32).' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'on | Doc txt :- 'All patients were administered Zynteglo with a median
#  HGB‑207, LTF‑303)' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'glo_clean_SmPC.json | Doc txt :- 'Figure 1            Median total haemoglobin over time in
#  days prior to the measurement date.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'n | Doc txt :- 'Total
#  who have not received transfusions in the prior 60 days. ' | Qrd txt :- '6.6 Special precautions for disposal <and other handling>' | Matched :- 'False'teglo_clean_SmPC.json | Doc txt :- '*Patients
#  study after medicinal product infusion.' | Qrd txt :- '6.5 Nature and contents of container <and special equipment for use administration or implantation>' | Matched :- 'False'Doc txt :- '**Transfusion
# 2021-05-20 00:23:38,395 : Heading Extraction Zynteglo_clean_SmPC.json_L : Match Passed | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | Doc txt :- 'Paediatric population' | Qrd txt :- 'Paediatric population' | Matched :- 'True'
# 2021-05-20 00:23:38,410 : Heading Extraction Zynteglo_clean_SmPC.json_L : Validation Failed As Wrong Heading Found | H | CAP |  en | 0 | Zynteglo_clean_SmPC.json | currHeadId :- '20013' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '20033'
# ...
# 2021-05-20 00:25:49,467 : Heading Extraction Zynteglo_clean_ PACKAGE LEAFLET.json_W : Validation Passed | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | currHeadId :- '23027' | prevHeadingCurrId :- '23026' | prevHeadingFoundId :- '23026'
#  leaflet was last revised in <{MM/YYYY}>' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False' 33)|0.53| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This
#  leaflet was last revised in <{MM/YYYY}>' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'True'97| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This
# 2021-05-20 00:25:49,737 : Heading Extraction Zynteglo_clean_ PACKAGE LEAFLET.json_W : Validation Passed | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | currHeadId :- '23028' | prevHeadingCurrId :- '23027' | prevHeadingFoundId :- '23027'
# 2021-05-20 00:25:49,745 : Heading Extraction Zynteglo_clean_ PACKAGE LEAFLET.json_W : Validation Failed By Style | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | currHeadId :- '23028' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '23027'
# ----------------------------------
# RemovedByStyle
# ----------------------------------
#  evidence to come about this medicine. ' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False', 33)|0.534| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This
#  evidence to come about this medicine. ' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'1| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This
#  every year and this leaflet will be updated as necessary.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'The
#  every year and this leaflet will be updated as necessary.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False' | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'The
#  of MS Agency (link)}>.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'e3|84.21|(17, 28, 86)|0.533| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Detailed
#  of MS Agency (link)}>.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'(16, 25, 86)|0.502| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Detailed
#  website.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'd : SpecialCase3|80.22|(14, 29, 36)|0.557| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This
#  website.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'alCase1|72.53|(36, 47, 86)|0.603| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This
# 2021-05-20 00:25:54,376 : Heading Extraction Zynteglo_clean_ PACKAGE LEAFLET.json_W : Match Failed : SpecialCase3|99.12|(1, 2, 0)|0.343| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- '-----------------------------------------------------------------------------------------------------------------' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'
#  intended for healthcare professionals only: ' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'0.592| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'The following information is
#  intended for healthcare professionals only: ' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'The following information is
# 2021-05-20 00:25:55,190 : Heading Extraction Zynteglo_clean_ PACKAGE LEAFLET.json_W : Match Passed | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'The following information is intended for healthcare professionals only:' | Qrd txt :- 'The following information is intended for healthcare professionals only:' | Matched :- 'True'
# 2021-05-20 00:25:55,206 : Heading Extraction Zynteglo_clean_ PACKAGE LEAFLET.json_W : Validation Flow Is Broken | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | currHeadId :- '23030' | prevHeadingCurrId :- '' | prevHeadingFoundId :- '23027'
# 2021-05-20 00:25:55,214 : Heading Extraction Zynteglo_clean_ PACKAGE LEAFLET.json_W : Validation Passed | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | currHeadId :- '23030' | prevHeadingCurrId :- '23027' | prevHeadingFoundId :- '23027'
#  infusion.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False' : SpecialCase3|84.77|(13, 34, 86)|0.53| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Confirm that Zynteglo is printed on
#  infusion.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'lCase1|85.79|(12, 24, 29)|0.438| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Confirm that Zynteglo is printed on
#  accompanying Lot Information Sheet. ' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'34, 86)|0.543| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Account for all infusion bags and
#  accompanying Lot Information Sheet. ' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'.484| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Account for all infusion bags and
#  contact bluebird bio immediately.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'8, 40, 86)|0.534| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Inspect each infusion bag for any
#  contact bluebird bio immediately.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False')|0.434| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Inspect each infusion bag for any
#  autologous use. ' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'ialCase3|95.74|(27, 29, 29)|0.569| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Zynteglo is intended solely for
#  autologous use. ' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'100.0|(19, 22, 29)|0.553| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Zynteglo is intended solely for
#  proceeding to thaw and infuse the next bag. ' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'.497| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Administer each infusion bag via
#  proceeding to thaw and infuse the next bag. ' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Administer each infusion bag via
#  Infuse as soon as possible and no more than 4 hours after thawing. ' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'| 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Zynteglo must not be re‑frozen.
#  Infuse as soon as possible and no more than 4 hours after thawing. ' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'teglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Zynteglo must not be re‑frozen.
#  patient.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'd : SpecialCase3|84.97|(15, 36, 86)|0.523| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Flush all Zynteglo remaining in the
#  patient.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'alCase1|84.46|(17, 38, 86)|0.473| | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Flush all Zynteglo remaining in the
#  material applicable for such products should be followed.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This medicinal product contains
#  material applicable for such products should be followed.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False' | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'This medicinal product contains
#  and eye protection) to avoid potential transmission of infectious diseases.' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'nteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Healthcare professionals handling
#  and eye protection) to avoid potential transmission of infectious diseases.' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'ean_ PACKAGE LEAFLET.json | Doc txt :- 'Healthcare professionals handling
#  viricidal disinfectant according to the manufacturer's instructions. ' | Qrd txt :- 'Pregnancy <and> <,> breast-feeding <and fertility>' | Matched :- 'False'3 | Zynteglo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Work surfaces and material which
#  viricidal disinfectant according to the manufacturer's instructions. ' | Qrd txt :- 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.' | Matched :- 'False'glo_clean_ PACKAGE LEAFLET.json | Doc txt :- 'Work surfaces and material which
# 2021-05-20 00:26:04,627 : Flow Logger HTML_2 : Completed Heading Extraction For File | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,630 : Flow Logger HTML_2 : 3: Heading Extraction,1.6099 Min,1.08169 MB,3.157027 MB,66.5%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,634 : Flow Logger HTML_2 : Starting Document Annotation For File | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,642 : Flow Logger HTML_2 : Completed Document Annotation | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,643 : Flow Logger HTML_2 : 3: Document Annotation,0.0002 Min,0.161992 MB,0.171669 MB,66.5%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,648 : Flow Logger HTML_2 : Starting Extracting Content Between Heading | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,655 : ExtractContentBetween_3_3 : Cleaning Match Results | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# 2021-05-20 00:26:04,661 : ExtractContentBetween_3_3 : Finished Cleaning Match Results | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# 2021-05-20 00:26:04,708 : Flow Logger HTML_2 : Completed Extracting Content Between Heading | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,709 : Flow Logger HTML_2 : 3: Content Extraction,0.001 Min,0.380609 MB,1.062733 MB,66.5%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:04,742 : XmlGeneration_3_j : PMS/OMS Annotation Information Not Retrieved | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# 2021-05-20 00:26:04,743 : XmlGeneration_3_j : Initiating XML Generation | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# Heading Not Found
#  ['q This medicine is subject to additional monitoring. This will allow quick identification of new safety information. You can help by reporting any side effects you may get. See the end of section 4 for how to report side effects.', 'Do not <take> <use> X', 'Children <and adolescents>', 'X with <food> <and> <,> <drink> <and> <alcohol>', 'X contains {name the excipient(s)}', 'How to <take> <use> X ', 'Use in children <and adolescents>', 'If you <take> <use> more X than you should', 'If you forget to <take> <use> X>', 'If you stop <taking> <using> X>', 'Additional side effects in children <and adolescents>', 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.', 'Other sources of information']
#
#
# dict_keys(['q This medicine is subject to additional monitoring. This will allow quick identification of new safety information. You can help by reporting any side effects you may get. See the end of section 4 for how to report side effects.', '1. What Zynteglo is and what it is used for', '2. What you need to know before you <take> <use> Zynteglo ', '4. Possible side effects', '5. How to store Zynteglo', '6. Contents of the pack and other information', 'This leaflet was last revised in <{MM/YYYY}><{month YYYY}>.'])
# Completed Heading Extraction For File
# Metrics : 3: Heading Extraction,1.6099 Min,1.08169 MB,3.157027 MB,66.5%
#
# Starting Document Annotation For File :- Zynteglo_clean_ PACKAGE LEAFLET.json
# Error Found
# Completed Document Annotation
# Metrics : 3: Document Annotation,0.0002 Min,0.161992 MB,0.171669 MB,66.5%
#
# Starting Extracting Content Between Heading For File :- Zynteglo_clean_ PACKAGE LEAFLET.json
# File being processed: F:\Projects\EMA\Repository\EMA EPI PoC\function_code\work\H\CAP\Zynteglo\en\2021-05-19T07-52-54Z\partitionedJSONs\Zynteglo_clean_ PACKAGE LEAFLET.json
# --------------------------------------------
# Completed Extracting Content Between Heading
# Metrics : 3: Content Extraction,0.001 Min,0.380609 MB,1.062733 MB,66.5%
#
# Already Exists
# 2021-05-20 00:26:04,906 : XmlGeneration_3_j : Writing to File:Zynteglo_clean_ PACKAGE LEAFLET.xml | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# 2021-05-20 00:26:04,910 : Flow Logger HTML_2 : 3: Generate XML,0.0033 Min,1.693886 MB,3.088085 MB,66.5%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# Metrics : 3: Generate XML,0.0033 Min,1.693886 MB,3.088085 MB,66.5%
# 2021-05-20 00:26:09,914 : XML Submission Logger_3_T : Initiating Submission To FHIR Server | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# 2021-05-20 00:26:09,916 : XML Submission Logger_3_T : Response{"resourceType":"Bundle","id":"89ea110f-6298-4063-841c-a840178dd623","meta":{"versionId":"1","lastUpdated":"2021-05-19T18:56:07.027+00:00"},"type":"collection","entry":[{"fullUrl":"urn:uuid:e70ed86c-e92a-4dc1-ab29-f56758656a93","resource":{"resourceType":"Bundle","id":"70c4c12a-bbc5-4008-a3b4-dfc01d978960","identifier":{"system":"http://ema.europa.eu/fhir/identifier/documentid","value":"${instance.bundle[n].Identifier}"},"type":"document","timestamp":"2021-05-19T18:56:04+00:00","entry":[{"fullUr | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# 2021-05-20 00:26:09,923 : XML Submission Logger_3_T : POST sucessful: XML added with id: 89ea110f-6298-4063-841c-a840178dd623 | H | CAP |  en | 3 | Zynteglo_clean_ PACKAGE LEAFLET.json
# 2021-05-20 00:26:09,929 : Flow Logger HTML_2 : 3: Submit FHIR Msg,0.0836 Min,0.221378 MB,1.073556 MB,66.8%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:09,932 : Flow Logger HTML_2 : Completed Processing Partitioned Jsons | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:09,935 : Flow Logger HTML_2 : 3: Completed,0.0 Min,0.150221 MB,0.152617 MB,66.8%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# 2021-05-20 00:26:09,938 : Flow Logger HTML_2 : Final Metrics,3.1923 Min,0.0 MB,10.13895 MB,66.8%
#  | H | CAP |  en | HTML | Zynteglo_clean.htm
# POST sucessful: XML added with id 89ea110f-6298-4063-841c-a840178dd623
# Metrics : 3: Submit FHIR Msg,0.0836 Min,0.221378 MB,1.073556 MB,66.8%
#
# Created XML File For :- Zynteglo_clean_ PACKAGE LEAFLET.json
# Metrics : 3: Completed,0.0 Min,0.150221 MB,0.152617 MB,66.8%
#
# Metrics : Final Metrics,3.1923 Min,0.0 MB,10.13895 MB,66.8%

# %%
a
# Out:
#       Bold                        Classes  \
# 0     True                  ['MsoNormal']
# 1    False                  ['MsoNormal']
# 2     True                  ['MsoNormal']
# 3    False                  ['MsoNormal']
# 4     True                  ['MsoNormal']
# 5    False                  ['MsoNormal']
# 6     True                  ['MsoNormal']
# 7    False                  ['MsoNormal']
# 8     True                  ['MsoNormal']
# 9    False                  ['MsoNormal']
# 10    True                  ['MsoNormal']
# 11   False                           None
# 12   False                           None
# 13   False                  ['MsoNormal']
# 14    True                  ['MsoNormal']
# 15   False                  ['MsoNormal']
# 16   False                  ['MsoNormal']
# 17   False                  ['MsoNormal']
# 18   False                  ['MsoNormal']
# 19   False                  ['MsoNormal']
# 20   False                  ['MsoNormal']
# 21   False                  ['MsoNormal']
# 22   False                  ['MsoNormal']
# 23   False                  ['MsoNormal']
# 24   False                  ['MsoNormal']
# 25   False                  ['MsoNormal']
# 26   False                  ['MsoNormal']
# 27   False                  ['MsoNormal']
# 28   False                  ['MsoNormal']
# 29   False                  ['MsoNormal']
# 30   False                  ['MsoNormal']
# 31    True                  ['MsoNormal']
# 32   False                  ['MsoNormal']
# 33   False                  ['MsoNormal']
# 34   False                  ['MsoNormal']
# 35   False                  ['MsoNormal']
# 36    True                  ['MsoNormal']
# 37   False                  ['MsoNormal']
# 38    True                  ['MsoNormal']
# 39   False                  ['MsoNormal']
# 40   False                  ['MsoNormal']
# 41   False                  ['MsoNormal']
# 42   False                  ['MsoNormal']
# 43   False                  ['MsoNormal']
# 44   False                  ['MsoNormal']
# 45    True                  ['MsoNormal']
# 46   False                  ['MsoNormal']
# 47    True                  ['MsoNormal']
# 48   False                  ['MsoNormal']
# 49   False                  ['MsoNormal']
# 50   False                  ['MsoNormal']
# 51   False                  ['MsoNormal']
# 52   False  ['MsoListParagraphCxSpFirst']
# 53   False   ['MsoListParagraphCxSpLast']
# 54    True                  ['MsoNormal']
# 55   False                  ['MsoNormal']
# 56   False                  ['MsoNormal']
# 57   False                  ['MsoNormal']
# 58   False                  ['MsoNormal']
# 59   False                  ['MsoNormal']
# 60   False                  ['MsoNormal']
# 61   False                  ['MsoNormal']
# 62   False                  ['MsoNormal']
# 63   False                  ['MsoNormal']
# 64   False                  ['MsoNormal']
# 65   False                  ['MsoNormal']
# 66   False                  ['MsoNormal']
# 67   False                  ['MsoNormal']
# 68   False                  ['MsoNormal']
# 69   False                  ['MsoNormal']
# 70   False                  ['MsoNormal']
# 71   False                  ['MsoNormal']
# 72   False                  ['MsoNormal']
# 73   False                  ['MsoNormal']
# 74   False                  ['MsoNormal']
# 75   False                  ['MsoNormal']
# 76   False                  ['MsoNormal']
# 77   False                  ['MsoNormal']
# 78   False                  ['MsoNormal']
# 79   False                  ['MsoNormal']
# 80   False                  ['MsoNormal']
# 81   False                  ['MsoNormal']
# 82   False                  ['MsoNormal']
# 83   False                  ['MsoNormal']
# 84   False                  ['MsoNormal']
# 85   False                  ['MsoNormal']
# 86   False                  ['MsoNormal']
# 87   False                  ['MsoNormal']
# 88   False                  ['MsoNormal']
# 89   False                  ['MsoNormal']
# 90   False                  ['MsoNormal']
# 91   False                  ['MsoNormal']
# 92   False                  ['MsoNormal']
# 93   False                  ['MsoNormal']
# 94   False                  ['MsoNormal']
# 95   False                  ['MsoNormal']
# 96   False                  ['MsoNormal']
# 97   False                  ['MsoNormal']
# 98   False                  ['MsoNormal']
# 99   False                  ['MsoNormal']
# 100  False                  ['MsoNormal']
# 101  False                  ['MsoNormal']
# 102  False                  ['MsoNormal']
# 103  False                  ['MsoNormal']
# 104  False                  ['MsoNormal']
# 105  False                  ['MsoNormal']
# 106  False                  ['MsoNormal']
# 107  False                  ['MsoNormal']
# 108  False                  ['MsoNormal']
# 109  False                  ['MsoNormal']
# 110  False                  ['MsoNormal']
# 111  False                  ['MsoNormal']
# 112  False                  ['MsoNormal']
# 113  False                  ['MsoNormal']
# 114  False                  ['MsoNormal']
# 115  False                           None
# 116  False                  ['MsoNormal']
# 117  False                           None
# 118  False                  ['MsoNormal']
# 119   True                  ['MsoNormal']
# 120  False                  ['MsoNormal']
# 121  False                  ['MsoNormal']
# 122  False                  ['MsoNormal']
# 123  False             ['MsoNormalTable']
# 124  False                  ['MsoNormal']
# 125  False                  ['MsoNormal']
# 126   True                  ['MsoNormal']
# 127  False                  ['MsoNormal']
# 128  False                  ['MsoNormal']
# 129  False                  ['MsoNormal']
# 130  False                  ['MsoNormal']
# 131  False             ['MsoNormalTable']
# 132  False                  ['MsoNormal']
# 133  False                  ['MsoNormal']
# 134  False                  ['MsoNormal']
# 135  False                  ['MsoNormal']
# 136  False                  ['MsoNormal']
# 137  False                  ['MsoNormal']
# 138  False                  ['MsoNormal']
# 139  False                  ['MsoNormal']
# 140  False                  ['MsoNormal']
# 141  False                  ['MsoNormal']
# 142  False                  ['MsoNormal']
# 143  False                  ['MsoNormal']
# 144  False                           None
# 145  False                           None
#
#                                                                                                                                                                                                      Element  \
# 0    <p align="center" class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;\r margin-bottom:0in;margin-left:27.0pt;text-align:center;text-indent:-27.0pt;\r line-height:normal"><b><span lang="EN-...
# 1                                                                                <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 2    <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New ...
# 3                                                       <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"></p>
# 4    <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New ...
# 5                                                       <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"></p>
# 6    <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New ...
# 7                                                       <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"></p>
# 8    <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New ...
# 9                                                       <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"></p>
# 10   <p class="MsoNormal" style="margin-top:0in;margin-right:70.8pt;margin-bottom:\r 0in;margin-left:85.05pt;text-indent:-35.4pt;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New ...
# 11                                                                             <span style='font-size:11.0pt;font-family:"Times New Roman",serif'><br clear="all" style="page-break-before:always"/> </span>
# 12                                                                                                                                                        <br clear="all" style="page-break-before:always"/>
# 13                                                                                                                                    <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 14   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:27.0pt;text-indent:-27.0pt;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New Ro...
# 15                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 16   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><u><span lang="EN-GB" style='font-family:\r "Times New Roman",serif'>Name and...
# 17                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 18   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Minaris\r Rege...
# 19   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Haidgraben\r 5...
# 20   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>85521\r Ottobr...
# 21   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>GERMANY</span>...
# 22                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 23   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><u><span lang="EN-GB" style='font-family:\r "Times New Roman",serif'>Name and...
# 24                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 25   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Minaris\r Rege...
# 26   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Haidgraben\r 5...
# 27   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>85521\r Ottobr...
# 28   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>GERMANY</span>...
# 29                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 30                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 31   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><a name="OLE_LINK2"><b><span lang="EN-GB" style='font-family:"Times New Roman...
# 32                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 33   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Medicinal\r pr...
# 34                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 35                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 36   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.25in;text-indent:-.25in;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New Roma...
# 37   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><u><span lang="EN-GB" style='font-family:\r "Times New Roman",serif'></span><...
# 38   <p class="MsoNormal" style="margin-top:0in;margin-right:-.05pt;margin-bottom:\r 0in;margin-left:.5in;text-indent:-.5in;line-height:normal"><span style="font-family:Symbol">·</span><b><span style='...
# 39                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 40   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The\r requirem...
# 41                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 42   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The\r marketin...
# 43   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><u><span lang="EN-GB" style='font-family:\r "Times New Roman",serif'></span><...
# 44   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><u><span lang="EN-GB" style='font-family:\r "Times New Roman",serif'></span><...
# 45   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.25in;text-indent:-.25in;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New Roma...
# 46   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><u><span lang="EN-GB" style='font-family:\r "Times New Roman",serif'></span><...
# 47   <p class="MsoNormal" style="margin-top:0in;margin-right:-.05pt;margin-bottom:\r 0in;margin-left:.5in;text-indent:-.5in;line-height:normal"><span style="font-family:Symbol">·</span><b><span style='...
# 48                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 49   <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The marketing\r authorisation holder (MAH) shall perform the requir...
# 50                                                                                                                                    <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 51                         <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>An updated RMP should be\r submitted:</span></p>
# 52   <p class="MsoListParagraphCxSpFirst" style="text-indent:-.25in"><span lang="EN-GB" style="font-family:Symbol">·</span><span lang="EN-GB" style='font-family:"Times New Roman",serif'>At\r the reques...
# 53   <p class="MsoListParagraphCxSpLast" style="text-indent:-.25in"><span lang="EN-GB" style="font-family:Symbol">·</span><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Whenever\r the r...
# 54   <p class="MsoNormal" style="margin-top:0in;margin-right:-.05pt;margin-bottom:\r 0in;margin-left:.5in;text-indent:-.5in;line-height:normal"><span lang="EN-GB" style="font-family:Symbol">·</span><b>...
# 55                                                                                                          <p class="MsoNormal" style="margin-bottom:0in;line-height:normal;page-break-after:\r avoid"></p>
# 56   <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Prior to launch of\r Zynteglo in each Member State the Marketing Au...
# 57                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 58   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The\r educatio...
# 59                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 60   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The\r MAH shal...
# 61                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 62   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.5in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style="font-family:Symbol">·</span><span...
# 63   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.5in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style="font-family:Symbol">·</span><span...
# 64                                                                               <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 65   <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The physician\r educational material </span></b><span lang="EN-G...
# 66   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 67   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 68   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 69                                                                                                                                    <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 70   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.5in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style="font-family:Symbol">·</span><b><s...
# 71   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 72   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 73   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 74   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 75   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 76   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 77   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 78   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 79   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:1.25in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",s...
# 80   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:1.25in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",s...
# 81   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:1.25in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",s...
# 82   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:1.25in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",s...
# 83   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:1.25in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",s...
# 84   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 85                                                                                                                                    <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 86   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.5in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style="font-family:Symbol">·</span><b><s...
# 87   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 88   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 89   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 90                                                                                                                                    <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 91   <p class="MsoNormal" style="margin-bottom:0in;line-height:normal;page-break-after:\r avoid"><b><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The\r patient information pack</span><...
# 92   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 93   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 94   <p class="MsoNormal" style="margin-top:0in;margin-right:0in;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</sp...
# 95                                                                                                                                    <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 96   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.5in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style="font-family:Symbol">·</span><b>...
# 97   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 98   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 99   <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 100  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 101  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 102  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 103  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 104                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 105  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.5in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style="font-family:Symbol">·</span><b>...
# 106  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 107  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 108  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 109  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 110  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 111  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:.75in;text-indent:-.25in;line-height:normal"><span lang="EN-GB" style='font-family:"Courier New"'>o</...
# 112                                                                                                                                   <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 113  <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The MAH shall ensure\r that in each Member State where Zynteglo is ...
# 114                                                                                                                                   <p class="MsoNormal" style="margin-bottom:0in;line-height:normal"></p>
# 115  <ul style="margin-top:0in" type="disc"> <li class="MsoNormal" style="margin-right:-.1pt;margin-bottom:0in;line-height:\r      normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'...
# 116  <li class="MsoNormal" style="margin-right:-.1pt;margin-bottom:0in;line-height:\r      normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>Zynteglo\r      will only be available ...
# 117  <span lang="EN-GB" style='font-family:"Times New Roman",serif'>Zynteglo\r      will only be available through bluebird bio qualified treatment centres to\r      ensure traceability of the patient`...
# 118                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 119  <p class="MsoNormal" style="margin-top:0in;margin-right:-.05pt;margin-bottom:\r 0in;margin-left:.5in;text-indent:-.5in;line-height:normal"><span style="font-family:Symbol">·</span><b><span style='...
# 120                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 121  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>The\r MAH shal...
# 122                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 123  <table border="1" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="width:98.0%;border-collapse:collapse;border:none" width="98%"> <tr> <td style="width:81.28%;border:solid windowtext ...
# 124                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 125                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 126  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:21.3pt;text-indent:-21.3pt;line-height:normal"><b><span lang="EN-GB" style='font-family:"Times New Ro...
# 127                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 128  <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"><span lang="EN-GB" style='font-family:"Times New Roman",serif'>This\r being a...
# 129                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 130                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 131  <table border="1" cellpadding="0" cellspacing="0" class="MsoNormalTable" style="border-collapse:collapse;border:none" width="98%"> <thead> <tr> <td style="width:81.1%;border:solid windowtext 1.0pt...
# 132                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 133                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 134                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 135                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 136                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 137                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 138                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 139                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 140                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 141                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 142                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 143                                                                              <p class="MsoNormal" style="margin-top:0in;margin-right:-.1pt;margin-bottom:0in;\r margin-left:0in;line-height:normal"></p>
# 144                                                                     <b><span style='font-size:11.0pt;font-family:"Times New Roman",serif'><br clear="all" style="page-break-before:always"/> </span></b>
# 145                                                                            <span style='font-size:11.0pt;font-family:"Times New Roman",serif'><br clear="all" style="page-break-before:always"/> </span>
#
#      HasBorder                                    ID  Indexed IsHeadingType  \
# 0        False  320efb82-a156-45a3-afdd-0e3a7e54d6da    False          None
# 1        False  f79ed8ed-bfc4-4e8b-bd49-ede302291e8a    False          None
# 2        False  7b2ff4b3-f27a-47ca-96a9-7ae24cfdefab     True            L1
# 3        False  d320b69e-a3c5-4764-aa31-251a32af8a17    False          None
# 4        False  e67b4687-f1a0-4608-988a-bcbb07029721     True            L1
# 5        False  a9013513-966a-4638-818e-90def54e0698    False          None
# 6        False  f9007321-3055-4120-b8ed-79e72cb470ae     True            L1
# 7        False  1b70d864-ef01-4bad-91f3-54dcbbe56cef    False          None
# 8        False  71e9cc22-be86-4f43-b932-f89b799916ba     True            L1
# 9        False  d7fd1fa1-ea7c-4b20-8b1b-11cbcafde70c    False          None
# 10       False  0b1e8d74-6436-4e36-bb4e-d86cf3d42102     True            L1
# 11       False  811ed5d1-2f76-4353-a18d-4116353e3d27    False          None
# 12       False  8503ed6e-6fca-423d-a497-a3c96d15c2b1    False          None
# 13       False  949e4e02-6863-437c-bf2c-de25daea7c48    False          None
# 14       False  265b3494-c1bd-4c7c-b42a-5ba19353f5fe     True            L1
# 15       False  bb93eaf6-c4c2-4b24-a197-c696d2773b87    False          None
# 16       False  31c07a18-a71b-48c9-aced-1885dc1b771f    False            L2
# 17       False  9331977e-66c3-496c-ad84-978d5030d2e7    False          None
# 18       False  d26b2974-eaa8-4931-9285-be740ca27b41    False          None
# 19       False  4d3368b6-74b1-4ae1-9333-7dee8ff09a3a    False          None
# 20       False  36859c33-dc05-439e-8082-bd5ea88f9c10    False          None
# 21       False  8aab741a-263b-4535-8325-e7fdb1a58f69    False          None
# 22       False  2e9bbdd3-8fb7-4cdf-851e-a16585c0a226    False          None
# 23       False  254fee23-9dff-4638-b207-798a6df69ee1    False            L2
# 24       False  c938afdd-9ddf-458c-aef1-280a74daee4f    False          None
# 25       False  0ebe695f-2898-43fd-8cc0-7439c73acadf    False          None
# 26       False  a2582864-95d1-4826-8663-06b0d8a5e326    False          None
# 27       False  6493efbe-0de2-43c0-9cf3-2ae7a1bb7f5c    False          None
# 28       False  e4f12316-a583-4774-b351-8d8070161b52    False          None
# 29       False  6f47f7db-8309-46a6-ad91-36bb083d1890    False          None
# 30       False  9c15fd76-560d-4ed6-85bb-e432deb0909c    False          None
# 31       False  f6504d1b-a54e-44ba-bd9f-e939dd3b64be     True            L1
# 32       False  88349e01-9c13-4d52-b451-40f5da340b9a    False          None
# 33       False  fd785dc0-2d98-4b84-a0e8-b3f1a4074df4    False          None
# 34       False  22d4b688-4362-4437-bed5-4131aedc28de    False          None
# 35       False  8d89c408-4d26-4d24-8e42-cb61ca6020e7    False          None
# 36       False  a6180394-06db-47fc-a056-73c7dc5c6476     True            L1
# 37       False  6f11fef0-370b-4c7a-ab5c-9ec896c6950c    False          None
# 38       False  17d29944-f2a5-49ae-834b-058ac5808193    False            L2
# 39       False  7ae908d4-7ee7-4836-9c89-75775319be33    False          None
# 40       False  ad7a1086-11fc-4809-8549-8b6aedc12501    False          None
# 41       False  c13b4678-07e7-4051-a740-721ba8643abe    False          None
# 42       False  1498a097-32a1-4b58-829a-cc3616537299    False          None
# 43       False  9cac6c0b-1972-4c45-b456-43f4afe8d8fb    False          None
# 44       False  2dd60d5a-9e5e-4351-8fb8-d78295874233    False          None
# 45       False  86f7961d-e6cb-4e12-9c9b-49478596cd0d     True            L1
# 46       False  bffde566-8f29-46b8-84ff-ec30278d09b3    False          None
# 47       False  fd9d695d-050b-424e-96ee-7c02281b3575    False            L2
# 48       False  32ca9f22-fd16-4ffc-aafd-c765085a70ab    False          None
# 49       False  bd94cb6e-4b1f-4fc5-a221-a3cee13e51f7    False          None
# 50       False  23e5504f-edc6-453c-a538-6ec6dbb559e9    False          None
# 51       False  2779b6f3-2b82-416c-8256-f821394685fe    False          None
# 52       False  1f3ee080-b69d-4c7f-a560-200682755170    False          None
# 53       False  2078d81f-fcbb-41f2-b737-9d68987b127b    False          None
# 54       False  8952dbee-1add-471e-acdb-d3053d637ee0    False            L2
# 55       False  c05c0a32-9f4f-4cb7-ab6c-031be2ff9249    False          None
# 56       False  22fe1264-147f-4d97-a90e-33c32d15debe    False          None
# 57       False  f2860c42-a599-4783-8845-19a658b64091    False          None
# 58       False  dadda308-362d-4ce6-9680-8f91549006a8    False          None
# 59       False  97404f68-2c89-4514-8397-8cb653e65930    False          None
# 60       False  190fffc1-bfc8-4d2c-b129-b956eddee785    False          None
# 61       False  43633714-9b8c-46cf-a6ae-ee523f677f55    False          None
# 62       False  5c4b634f-5f72-4382-9f08-9aafac91eb96    False          None
# 63       False  7d55ef15-3197-4c33-b24e-affd7bc5a7a0    False          None
# 64       False  41409b7e-0c89-4def-a101-3847ea75462e    False          None
# 65       False  3f0295f6-1601-4dcb-b22c-76b76253e8a5    False          None
# 66       False  111c4419-1407-4875-9431-ffa01b70f2ad    False          None
# 67       False  ad7ef8c2-2b09-44f5-896e-2ddef1687a35    False          None
# 68       False  ceabb82f-aaa8-42a2-9748-3785695a2bb7    False          None
# 69       False  1919a207-6e1c-4e93-ad24-7cb545b3dfe2    False          None
# 70       False  8c1fd9f3-b755-4472-998f-af0cdc3db13c    False          None
# 71       False  00d13ded-3a97-45ae-a6f9-9225114c8f5f    False          None
# 72       False  79925c63-8fa9-4816-8db2-9520b4c3d90c    False          None
# 73       False  35c30da0-a276-4883-868a-cd6f06a28d96    False          None
# 74       False  815f3d31-12d1-48e4-98a3-1f55e5a3dde7    False          None
# 75       False  c94dfaff-dff4-478c-bbaa-93f9977e1c9d    False          None
# 76       False  9f04c709-6f24-4a7e-8819-2f6c8e820c03    False          None
# 77       False  356a0871-b9b9-47de-8354-60a04f756df4    False          None
# 78       False  759631c3-a28a-438a-9f5a-670b07fa5a71    False          None
# 79       False  38410076-7808-4ad4-8693-89bc2876a581    False          None
# 80       False  5c70a030-2a11-4a5a-8aae-710c70f3bc9d    False          None
# 81       False  5e9f4188-29c4-41a9-8725-286b600afa41    False          None
# 82       False  316afac6-c2d5-4a71-8b60-176737dc5f06    False          None
# 83       False  7e81e8eb-d8a2-451a-88c7-98c0c6712514    False          None
# 84       False  4cc61485-62bd-4c6e-a0f2-6e7a4d8687d3    False          None
# 85       False  4e4e7fe5-b90d-45f7-aff5-f82f5364a23a    False          None
# 86       False  ff683f28-2449-4c99-89e7-aa132f19b798    False          None
# 87       False  6d897643-9fe6-4505-8b48-7c4d0b5010ac    False          None
# 88       False  c0f5d7b4-27f9-4b7d-a512-24fd93de1bf9    False          None
# 89       False  5d3b6062-72d3-40df-955c-2cba0268ad1a    False          None
# 90       False  a7978361-fc6b-40f3-befa-63dedea0edf0    False          None
# 91       False  1a02cd8f-9074-458b-ba78-3e77481ccb1d    False          None
# 92       False  e3e918d2-f8d8-4f29-894a-097ef7379d4c    False          None
# 93       False  7b6228b8-e418-4bfa-8ec8-e777726d40a4    False          None
# 94       False  b1336077-5c29-4f30-bfc9-471f4515adc1    False          None
# 95       False  c9fe2f4e-bed2-48bd-93c1-98d20791288b    False          None
# 96       False  4a0452ac-5958-48f9-9746-ba6ca04113ee    False          None
# 97       False  baf65bab-0f3c-4c00-a749-1aad35fb0c94    False          None
# 98       False  81485283-1eac-44cc-ac0f-519981ec10c7    False          None
# 99       False  abd5075a-0cb4-4dab-abb0-cc601f4d34a4    False          None
# 100      False  4214d574-8c36-443b-b043-93752948ca53    False          None
# 101      False  395166a4-6ed8-4740-a884-c4a1cde380fb    False          None
# 102      False  7e44e0eb-0d16-416e-82b8-4d44dcdadba7    False          None
# 103      False  70b4a970-b12d-46e2-8abc-5f1ee39e3fb5    False          None
# 104      False  3a7350b7-a792-43fa-a475-982eb9c9568a    False          None
# 105      False  404e3d6b-e526-4fa3-8652-4a9586d13a11    False          None
# 106      False  de8a5b49-bb94-4468-957c-dd9cda389208    False          None
# 107      False  1f8b0734-dafb-46ef-aae5-2620c47bbde1    False          None
# 108      False  87ba1f34-b702-4efd-bcd1-f99fd47de765    False          None
# 109      False  8d761a10-1b4f-4e1e-9e16-92768d27d47b    False          None
# 110      False  b11ed372-e2c2-4562-9ce2-095b10e1c7be    False          None
# 111      False  a7128fc9-7848-4998-b585-39113a6ecafe    False          None
# 112      False  7b694ca0-6c04-4ae5-9276-d05f231b0e3f    False          None
# 113      False  7a587605-20db-4360-ade8-b7e73f0a88f9    False          None
# 114      False  493a4069-ed66-4b15-8646-3648042c2c9d    False          None
# 115      False  2d13bc6d-9698-4c7f-a0c2-6ff800838514    False          None
# 116      False  e8d2d011-8a6a-4bf9-bd35-ccebe3d4db7f    False          None
# 117      False  61af711e-b945-4aec-a503-68c11b15d62a    False          None
# 118      False  658bdfa2-7e00-4bfc-8420-a4d72b1e490c    False          None
# 119      False  65750a5a-3b1e-4c4e-9049-7edf80ebc435    False            L2
# 120      False  da10bcd4-ee06-47b1-8582-1f7d75b4810f    False          None
# 121      False  146212ee-2a1e-4d7e-80fa-cc926f47049a    False          None
# 122      False  d85e4e81-85f2-4eff-baf3-a50955a75d78    False          None
# 123      False  46b08708-fd77-4d2d-a1d8-b1c63968bec6    False          None
# 124      False  9dcbb69d-a8f4-4863-9d93-04caf1b8d3cc    False          None
# 125      False  fff7c337-bcd0-4e2b-a2b5-6aeddb865980    False          None
# 126      False  71a3fb41-1b96-4542-b8ec-e1ada12c3b1f     True            L1
# 127      False  86506ae1-9b03-4513-8695-4563e96f142c    False          None
# 128      False  359c584f-4887-4bc4-a075-11c35d27d8e0    False          None
# 129      False  c0ceb45d-8b2c-45d9-a361-0648972fc13d    False          None
# 130      False  ad848f23-8eba-4e18-8b43-2f6d9be6ea4f    False          None
# 131      False  2d3ef400-17a1-4e65-9c0f-d45b768d78e5    False          None
# 132      False  38307fa5-8b6d-4324-b553-c7524b46b66c    False          None
# 133      False  bf0894a0-bc69-478a-a0d9-d0273b48a863    False          None
# 134      False  e785e519-38e9-4221-b4aa-a9343e412712    False          None
# ...
# 101                                                         oTreatment\r with Zynteglo is associated with the risk of delayed platelet engraftment that\r could lead to an increased tendency for bleeding.
# 102                                         oSigns\r and symptoms of bleeding and the need to contact the physician if any signs of\r unusual or prolonged bleeding or any other relevant signs are present.
# 103                                                                                                                                                               oEnrolment\r in the drug product Registry.
# 104
# 105                                                                                                                                    ·The\r patient alert card\r shall contain the following key messages:
# 106                                                                                          oInformation\r of risk of delayed platelet engraftment, potentially leading to bleeds, and\r theoretical risks.
# 107                                                                                    oStatement\r that the patient was treated with gene therapy and should not donate blood,\r organs, tissues, or cells.
# 108                                                                                                   oStatement\r that the patient was treated with Zynteglo, including LOT number and treatment\r date(s).
# 109                                                                                                                                                              oDetails\r on reporting of adverse effects.
# 110                                                                                             oInformation\r on the possibility of false positivity of certain commercial HIV tests because\r of Zynteglo.
# 111                                                                                                                     oContact\r details where a health care professional can receive further information.
# 112
# 113  The MAH shall ensure\r that in each Member State where Zynteglo is marketed, a system aimed to control\r distribution to Zynteglo beyond the level of control ensured by routine risk\r minimisation...
# 114
# 115
# 116
# 117  Zynteglo\r      will only be available through bluebird bio qualified treatment centres to\r      ensure traceability of the patient`s cells and manufactured drug product\r      between the treati...
# 118
# 119                                                                                                                                                    ·Obligation\r to conduct post-authorisation measures
# 120
# 121                                                                                                                               The\r MAH shall complete, within the stated timeframe, the below measures:
# 122
# 123     Description   Due date     In\r   order to further confirm the appropriateness of the acceptance criteria, the\r   MAH should re-evaluate the acceptance criteria for attributes related to\r   p...
# 124
# 125
# 126                                                                                        E.    SPECIFIC OBLIGATION TO\r COMPLETE POST-AUTHORISATION MEASURES FOR THE CONDITIONAL MARKETING\r AUTHORISATION
# 127
# 128        This\r being a conditional marketing authorisation and pursuant to Article 14(7) of\r Regulation (EC) No 726/2004, the MAH shall complete, within the stated\r timeframe, the following measures:
# 129
# 130
# 131      Description   Due date      In order to confirm the efficacy and safety of\r   Zynteglo in patients 12 years and older with transfusion-dependent\r   β-thalassaemia (TDT) who do not have a β0/...
# 132
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
#
#      Underlined  Uppercased  StringLength
# 0         False        True             8
# 1         False       False             0
# 2         False        True           106
# 3         False       False             0
# 4         False        True            54
# 5         False       False             0
# 6         False        True            67
# 7         False       False             0
# 8         False        True            96
# 9         False       False             0
# 10        False        True           106
# 11        False       False             0
# 12        False       False             0
# 13        False       False             0
# 14        False        True           106
# 15        False       False             0
# 16         True       False            77
# 17        False       False             0
# 18        False       False            34
# 19        False       False            12
# 20        False       False            15
# 21        False        True             7
# 22        False       False             0
# 23         True       False            69
# 24        False       False             0
# 25        False       False            34
# 26        False       False            12
# 27        False       False            15
# 28        False        True             7
# 29        False       False             0
# 30        False       False             0
# 31        False        True            54
# 32        False       False             0
# 33        False       False           136
# 34        False       False             0
# 35        False       False             0
# 36        False        True            67
# 37        False       False             0
# 38        False       False            39
# 39        False       False             0
# 40        False       False           262
# 41        False       False             0
# 42        False       False           126
# 43        False       False             0
# 44        False       False             0
# 45        False        True            96
# 46        False       False             0
# 47        False       False            27
# 48        False       False             0
# 49        False       False           244
# 50        False       False             0
# 51        False       False            35
# 52        False       False            49
# 53        False       False           273
# 54        False       False            38
# 55        False       False             0
# 56        False       False           322
# 57        False       False             0
# 58        False       False           116
# 59        False       False             0
# 60        False       False           298
# 61        False       False             0
# 62        False       False            31
# 63        False       False            25
# 64        False       False             0
# 65        False       False            50
# 66        False       False            39
# 67        False       False            35
# 68        False       False            49
# 69        False       False             0
# 70        False       False            81
# 71        False       False           113
# 72        False       False           414
# 73        False       False           259
# 74        False       False           117
# 75        False       False           187
# 76        False       False           177
# 77        False       False           150
# 78        False       False            60
# 79        False       False            43
# 80        False       False            52
# 81        False       False            27
# 82        False       False            86
# 83        False       False            40
# 84        False       False            49
# 85        False       False             0
# 86        False       False           122
# 87        False       False           100
# 88        False       False            43
# 89        False       False            62
# 90        False       False             0
# 91        False       False            44
# 92        False       False            16
# 93        False       False            22
# 94        False       False            22
# 95        False       False             0
# 96        False       False            66
# 97        False       False           182
# 98        False       False           144
# 99        False       False           187
# 100       False       False            36
# 101       False       False           139
# 102       False       False           156
# 103       False       False            40
# 104       False       False             0
# 105       False       False            65
# 106       False       False           107
# 107       False       False           113
# 108       False       False            98
# 109       False       False            41
# 110       False       False           104
# 111       False       False            82
# 112       False       False             0
# 113       False       False           316
# 114       False       False             0
# 115       False       False             0
# 116       False       False             0
# 117       False       False           333
# 118       False       False             0
# 119       False       False            50
# 120       False       False             0
# 121       False       False            72
# 122       False       False             0
# 123       False       False          1023
# 124       False       False             0
# 125       False       False             0
# 126       False        True           106
# 127       False       False             0
# 128       False       False           187
# 129       False       False             0
# 130       False       False             0
# 131       False       False          1020
# 132       False       False             0
# 133       False       False             0
# 134       False       False             0
# 135       False       False             0
# 136       False       False             0
# 137       False       False             0
# 138       False       False             0
# 139       False       False             0
# 140       False       False             0
# 141       False       False             0
# 142       False       False             0
# 143       False       False             0
# 144       False       False             0
# 145       False       False             0

# %%
convertCollectionToDataFrame(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c25aadffa48e> in <module>
# ----> 1 convertCollectionToDataFrame(b)
#
# NameError: name 'b' is not defined
